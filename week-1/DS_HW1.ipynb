# %% [markdown]
# # CS 109A/STAT 121A/AC 209A/CSCI E-109A: Homework 1
#
#
#
# **Harvard University**<br/>
# **Fall 2017**<br/>
# **Instructors**: Pavlos Protopapas, Kevin Rader, Rahul Dave, Margo Levine
#
# ---
#
# ### INSTRUCTIONS
#
# **WARNING**: There is web page scraping in this homework. It takes about 40 minutes. **Do not wait till the last minute** to do this homework.
#
# - To submit your assignment follow the instructions given in canvas.
# - Restart the kernel and run the whole notebook again before you submit. There is an important CAVEAT to this. DO NOT run the web-page fetching cells again. (We have provided hints like `# DO NOT RERUN THIS CELL WHEN SUBMITTING` on some of the cells where we provide the code). Instead load your data structures from the JSON files we will ask you to save below. Otherwise you will be waiting for a long time. (Another reason to not wait until the last moment to submit.)
#
# - Do not include your name in the notebook.
#
# ---

# %%
import os
os.environ['HTTP_PROXY'] = 'http://vamshikrishna0997:msit1234@10.10.10.3:3128'
os.environ['HTTPS_PROXY']='https://vamshikrishna0997:msit1234@10.10.10.3:3128'

# %% [markdown]
# # Homework 1: Rihanna or Mariah?

# %% [markdown]
# Billboard Magazine puts out a top 100 list of "singles" every week. Information from this list, as well as that from music sales, radio, and other sources is used to determine a top-100 "singles" of the year list. A **single** is typically one song, but sometimes can be two songs which are on one "single" record.
#
# In this homework you will:
#
# 1. Scrape Wikipedia to obtain infprmation about the best singers and groups from each year (distinguishing between the two groups) as determined by the Billboard top 100 charts. You will have to clean this data. Along the way you will learn how to save data in json files to avoid repeated scraping.
# 2. Scrape Wikipedia to obtain information on these singers. You will have to scrape the web pages, this time using a cache to guard against network timeouts (or your laptop going to sleep). You will again clean the data, and save it to a json file.
# 3. Use pandas to represent these two datasets and merge them.
# 4. Use the individual and merged datasets to visualize the performance of the artists and their songs. We have kept the amount of analysis limited here for reasons of time; but you might enjoy exploring music genres and other aspects of the music business you can find on these wikipedia pages at your own leisure.

# %% [markdown]
# You should have worked through Lab0 and Lab 1, and Lecture 2.  Lab 2 will help as well.

# %% [markdown]
# As usual, first we import the necessary libraries.  In particular, we use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to give us a nicer default color palette, with our plots being of large (`poster`) size and with a white-grid background.

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# ## Q1. Scraping Wikipedia for Billboard Top 100.

# %% [markdown]
# In this question you will scrape Wikipedia for the Billboard's top 100 singles.

# %% [markdown]
# ### Scraping Wikipedia for Billboard singles

# %% [markdown]
# We'll be using  [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/), and suggest that you use Python's built in `requests` library to fetch the web page.

# %%
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %% [markdown]
# #### 1.1 Parsing the Billboard Wikipedia page for 1970

# %% [markdown]
# Obtain the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970 using a HTTP GET request. From this web page we'll extract the top 100 singles and their rankings. Create a list of dictionaries, 100 of them to be precise, with entries like
#
# `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`.
#
# If you look at that web page, you'll see a link for every song, from which you can get the `url` of the singer or band. We will use these links later to scrape information about the singer or band. From the listing we can also get the band or singer name `band_singer`, and `title` of the song.
#
# *HINT: look for a table with class `wikitable`.*

# %%
my_url = "http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970"
uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()

# %%
rsoup = soup(page_html, "html.parser")

# %%
songsinfo = []

wikitable = rsoup.find('table', {'class': 'wikitable sortable'}).find_all("td")

for wiki in range(0,len(wikitable),3):
    songs = {'band_singer': wikitable[wiki+2].text.replace("\n",""), 'ranking': int(wikitable[wiki].text),
             'title': wikitable[wiki+1].text.replace("\n",""), 'url': wikitable[wiki+2].find('a').get("href")}
    songsinfo.append(songs)
    
print(songsinfo[2:4])
# Out:
# [{'band_singer': 'The Guess Who', 'ranking': 3, 'title': '"American Woman"', 'url': '/wiki/The_Guess_Who'}, {'band_singer': 'B.J. Thomas', 'ranking': 4, 'title': '"Raindrops Keep Fallin\' on My Head"', 'url': '/wiki/B.J._Thomas'}]

# %% [markdown]
# You should get something similar to this (where songs is the aforementioned list):
#
# ```
# songs[2:4]
# ```
#
# ```
# [{'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'title': '"American Woman"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'title': '"Raindrops Keep Fallin\' on My Head"',
#   'url': '/wiki/B.J._Thomas'}]
# ```

# %% [markdown]
# #### 1.2 Generalize the previous: scrape Wikipedia from 1992 to 2014

# %% [markdown]
# By visiting the urls similar to the ones for 1970, we can obtain the billboard top 100 for the years 1992 to 2014. (We choose these later years rather than 1970 as you might find music from this era more interesting.) Download these using Python's `requests` module and store the text from those requests in a dictionary called `yearstext`. This dictionary ought to have as its keys the years (as integers from 1992 to 2014), and as values corresponding to these keys the text of the page being fetched.
#
# You ought to sleep a second (look up `time.sleep` in Python) at the very least in-between fetching each web page: you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %% [markdown]
# *HINT: you might find `range` and string-interpolation useful to construct the URLs *.

# %%
yearshtml = []

for year in range(1992,2015):
    my_url = "http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_" + str(year)
#     print(my_url)
    uClient = uReq(my_url)
    yearshtml.append(uClient.read())
    uClient.close()

# %%
top100songsyear = {}
rsoup = soup(yearshtml[0], "html.parser")
songsinfo = []
wikitable = rsoup.find('table', {'class': 'wikitable sortable'}).find_all("tr")
        
        
for year in range(0, 23):
    rsoup = soup(yearshtml[year], "html.parser")
    
    songsinfo = []
    wikitable = rsoup.find('table', {'class': 'wikitable sortable'}).find_all("tr")
    for wiki in range(1,len(wikitable)):
        s = wikitable[wiki].find_all("td")
        if(s[0].find('a') != None):
            ur = s[0].find('a').get("href").strip()
            titl = s[0].find('a').text.strip()
        else:
            ur = None
            titl = s[0].text
        if(s[1].find('a') != None):
            sur = s[1].find('a').get("href").strip()
        else:
            sur = None
        songs = {'year': year + 1992,'band_singer': s[1].text.strip(), 'ranking': int(wikitable[wiki].find("th").text.strip()),
                  'song': titl,'songurl': sur,'title': titl, 'url': ur}
        songsinfo.append(songs)
        
        top100songsyear[year+1992] = songsinfo

# %%
print(top100songsyear[1997])
# Out:
# [{'year': 1997, 'band_singer': 'Elton John', 'ranking': 1, 'song': 'Something About the Way You Look Tonight', 'songurl': '/wiki/Elton_John', 'title': 'Something About the Way You Look Tonight', 'url': '/wiki/Something_About_the_Way_You_Look_Tonight'}, {'year': 1997, 'band_singer': 'Jewel', 'ranking': 2, 'song': 'Foolish Games', 'songurl': '/wiki/Jewel_(singer)', 'title': 'Foolish Games', 'url': '/wiki/Foolish_Games'}, {'year': 1997, 'band_singer': 'Puff Daddy featuring Faith Evans and 112', 'ranking': 3, 'song': "I'll Be Missing You", 'songurl': '/wiki/Sean_Combs', 'title': "I'll Be Missing You", 'url': '/wiki/I%27ll_Be_Missing_You'}, {'year': 1997, 'band_singer': 'Toni Braxton', 'ranking': 4, 'song': 'Un-Break My Heart', 'songurl': '/wiki/Toni_Braxton', 'title': 'Un-Break My Heart', 'url': '/wiki/Un-Break_My_Heart'}, {'year': 1997, 'band_singer': 'Puff Daddy featuring Mase', 'ranking': 5, 'song': "Can't Nobody Hold Me Down", 'songurl': '/wiki/Sean_Combs', 'title': "Can't Nobody Hold Me Down", 'url': '/wiki/Can%27t_Nobody_Hold_Me_Down'}, {'year': 1997, 'band_singer': 'R. Kelly', 'ranking': 6, 'song': 'I Believe I Can Fly', 'songurl': '/wiki/R._Kelly', 'title': 'I Believe I Can Fly', 'url': '/wiki/I_Believe_I_Can_Fly'}, {'year': 1997, 'band_singer': 'En Vogue', 'ranking': 7, 'song': "Don't Let Go (Love)", 'songurl': '/wiki/En_Vogue', 'title': "Don't Let Go (Love)", 'url': '/wiki/Don%27t_Let_Go_(Love)'}, {'year': 1997, 'band_singer': 'Mark Morrison', 'ranking': 8, 'song': 'Return of the Mack', 'songurl': '/wiki/Mark_Morrison', 'title': 'Return of the Mack', 'url': '/wiki/Return_of_the_Mack'}, {'year': 1997, 'band_singer': 'LeAnn Rimes', 'ranking': 9, 'song': 'How Do I Live', 'songurl': '/wiki/LeAnn_Rimes', 'title': 'How Do I Live', 'url': '/wiki/How_Do_I_Live'}, {'year': 1997, 'band_singer': 'Spice Girls', 'ranking': 10, 'song': 'Wannabe', 'songurl': '/wiki/Spice_Girls', 'title': 'Wannabe', 'url': '/wiki/Wannabe'}, {'year': 1997, 'band_singer': 'Backstreet Boys', 'ranking': 11, 'song': 'Quit Playing Games (With My Heart)', 'songurl': '/wiki/Backstreet_Boys', 'title': 'Quit Playing Games (With My Heart)', 'url': '/wiki/Quit_Playing_Games_(With_My_Heart)'}, {'year': 1997, 'band_singer': 'Hanson', 'ranking': 12, 'song': 'MMMBop', 'songurl': '/wiki/Hanson_(band)', 'title': 'MMMBop', 'url': '/wiki/MMMBop'}, {'year': 1997, 'band_singer': 'Monica', 'ranking': 13, 'song': 'For You I Will', 'songurl': '/wiki/Monica_(singer)', 'title': 'For You I Will', 'url': '/wiki/For_You_I_Will_(Monica_song)'}, {'year': 1997, 'band_singer': 'Usher', 'ranking': 14, 'song': 'You Make Me Wanna...', 'songurl': '/wiki/Usher_(entertainer)', 'title': 'You Make Me Wanna...', 'url': '/wiki/You_Make_Me_Wanna...'}, {'year': 1997, 'band_singer': 'Meredith Brooks', 'ranking': 15, 'song': 'Bitch', 'songurl': '/wiki/Meredith_Brooks', 'title': 'Bitch', 'url': '/wiki/Bitch_(Meredith_Brooks_song)'}, {'year': 1997, 'band_singer': 'Keith Sweat featuring Athena Cage', 'ranking': 16, 'song': 'Nobody', 'songurl': '/wiki/Keith_Sweat', 'title': 'Nobody', 'url': '/wiki/Nobody_(Keith_Sweat_song)'}, {'year': 1997, 'band_singer': 'Third Eye Blind', 'ranking': 17, 'song': 'Semi-Charmed Life', 'songurl': '/wiki/Third_Eye_Blind', 'title': 'Semi-Charmed Life', 'url': '/wiki/Semi-Charmed_Life'}, {'year': 1997, 'band_singer': 'Duncan Sheik', 'ranking': 18, 'song': 'Barely Breathing', 'songurl': '/wiki/Duncan_Sheik', 'title': 'Barely Breathing', 'url': '/wiki/Barely_Breathing'}, {'year': 1997, 'band_singer': 'Az Yet featuring Peter Cetera', 'ranking': 19, 'song': "Hard to Say I'm Sorry", 'songurl': '/wiki/Az_Yet', 'title': "Hard to Say I'm Sorry", 'url': '/wiki/Hard_to_Say_I%27m_Sorry'}, {'year': 1997, 'band_singer': 'The Notorious B.I.G. featuring Puff Daddy and Mase', 'ranking': 20, 'song': 'Mo Money Mo Problems', 'songurl': '/wiki/The_Notorious_B.I.G.', 'title': 'Mo Money Mo Problems', 'url': '/wiki/Mo_Money_Mo_Problems'}, {'year': 1997, 'band_singer': 'The Verve Pipe', 'ranking': 2 ...

# %% [markdown]
# #### 1.3 Parse and Clean data

# %% [markdown]
# Remember the code you wrote to get data from 1970 which produces a list of dictionaries, one corresponding to each single.  Now write a function `parse_year(the_year, yeartext_dict)` which takes the year, prints it out, gets the text for the year from the just created `yearstext` dictionary, and return a list of dictionaries for that year, with one dictionary for each single. Store this list in the variable `yearinfo`.
#
# The dictionaries **must** be of this form:
#
# ```
# {'band_singer': ['Brandy', 'Monica'],
#   'ranking': 2,
#   'song': ['The Boy Is Mine'],
#   'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
#   'titletext': '" The Boy Is Mine "',
#   'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
# ```

# %%
def parseyear(the_year, yeartext_dict):
    yeardict = []
    for i in yeartext_dict[the_year]:
        if i['band_singer'] != None:
            band = i['band_singer'].split("featuring")
            if(len(band) <= 1):
                 band = i['band_singer'].split(",")
        else:
            band = [None]
        if i['song'] != None:
            song = i['song'].split("/")
        else:
            song = [None]
        if i['songurl'] != None:
            songurl = i['songurl'].split(",")
        else:
            songurl = [None]
        if i['url'] != None:
            url = i['url'].split(",")
        else:
            url = [None]
        samp = {'year': i['year'],'band_singer': band, 'ranking': i['ranking'],'song': song, 'songurl': url, 'titletext': i['title'], 'url': songurl}
        yeardict.append(samp)
    return yeardict
    
yearinfo = parseyear(1997, top100songsyear)
yearinfo[:5]
# Out:
# [{'year': 1997,
#   'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight'],
#   'titletext': 'Something About the Way You Look Tonight',
#   'url': ['/wiki/Elton_John']},
#  {'year': 1997,
#   'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games'],
#   'songurl': ['/wiki/Foolish_Games'],
#   'titletext': 'Foolish Games',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'year': 1997,
#   'band_singer': ['Puff Daddy ', ' Faith Evans and 112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': "I'll Be Missing You",
#   'url': ['/wiki/Sean_Combs']},
#  {'year': 1997,
#   'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': 'Un-Break My Heart',
#   'url': ['/wiki/Toni_Braxton']},
#  {'year': 1997,
#   'band_singer': ['Puff Daddy ', ' Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': "Can't Nobody Hold Me Down",
#   'url': ['/wiki/Sean_Combs']}]

# %% [markdown]
# The spec of this function is provided below:

# %%
"""
Function
--------
parse_year

Inputs
------
the_year: the year you want the singles for
yeartext_dict: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    

Notes
-----
See description and example above.
"""
# Out:
# '\nFunction\n--------\nparse_year\n\nInputs\n------\nthe_year: the year you want the singles for\nyeartext_dict: a dictionary with keys as integer years and values the downloaded web pages \n    from wikipedia for that year.\n   \nReturns\n-------\n\na list of dictionaries, each of which corresponds to a single and has the\nfollowing data:\n\nEg:\n\n{\'band_singer\': [\'Brandy\', \'Monica\'],\n  \'ranking\': 2,\n  \'song\': [\'The Boy Is Mine\'],\n  \'songurl\': [\'/wiki/The_Boy_Is_Mine_(song)\'],\n  \'titletext\': \'" The Boy Is Mine "\',\n  \'url\': [\'/wiki/Brandy_Norwood\', \'/wiki/Monica_(entertainer)\']}\n  \nA dictionary with the following data:\n    band_singer: a list of bands/singers who made this single\n    song: a list of the titles of songs on this single\n    songurl: a list of the same size as song which has urls for the songs on the single \n        (see point 3 above)\n    ranking: ranking of the single\n    titletext: the contents of the table cell\n    band_singer: a list of bands or singers on this single\n    url: a list of wikipedia singer/band urls on this single: only put in the part \n        of the url from /wiki onwards\n    \n\nNotes\n-----\nSee description and example above.\n'

# %% [markdown]
# #### Helpful notes
#
# Notice that some singles might have multiple songs:
#
# ```
# {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']}
# ```

# %% [markdown]
# And some singles don't have a song URL:
#
# ```
# {'band_singer': [u'Nu Flavor'],
#   'ranking': 91,
#   'song': [u'Heaven'],
#   'songurl': [None],
#   'titletext': u'"Heaven"',
#   'url': [u'/wiki/Nu_Flavor']}
# ```

# %% [markdown]
# Thus there are some issues this function must handle:
#
# 1. There can be more than one  `band_singer` as can be seen above (sometimes with a comma, sometimes with "featuring" in between). The best way to parse these is to look for the urls.
# 2. There can be two songs in a single, because of the way the industry works: there are two-sided singles. See https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997 for an example. You can find other examples in 1998 and 1999.
# 3. The `titletext` is the contents of the table cell, and retains the quotes that Wikipedia puts on the single.
# 4. If no song anchor is found (see the 24th song in the above url), assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped (ie `song` is a one-element list with this the `titletext` stripped of its quotes).

# %% [markdown]
# As a check, we can do this for 1997. We'll print the first 5 outputs: `parse_year(1997, yearstext)[:5]`

# %% [markdown]
# This should give the following. Notice that the year 1997 exercises the edge cases we talked about earlier.

# %% [markdown]
# ```
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '" Something About the Way You Look Tonight " / " Candle in the Wind 1997 "',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '" I\'ll Be Missing You "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '" Un-Break My Heart "',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '" Can\'t Nobody Hold Me Down "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]
# ```

# %% [markdown]
# #### Save a json file of information from the scraped files

# %% [markdown]
# We do not want to lose all this work, so let's save the last data structure we created to disk. That way if you need to re-run from here, you don't need to redo all these requests and parsing.
#
# DO NOT RERUN THE HTTP REQUESTS TO WIKIPEDIA WHEN SUBMITTING.
#
# *We **DO NOT** need to see these JSON files in your submission!*

# %%
import json

# %%
top100songsyear
# Out:
# {1992: [{'year': 1992,
#    'band_singer': 'Boyz II Men',
#    'ranking': 1,
#    'song': 'End of the Road',
#    'songurl': '/wiki/Boyz_II_Men',
#    'title': 'End of the Road',
#    'url': '/wiki/End_of_the_Road'},
#   {'year': 1992,
#    'band_singer': 'Sir Mix-a-Lot',
#    'ranking': 2,
#    'song': 'Baby Got Back',
#    'songurl': '/wiki/Sir_Mix-a-Lot',
#    'title': 'Baby Got Back',
#    'url': '/wiki/Baby_Got_Back'},
#   {'year': 1992,
#    'band_singer': 'Kris Kross',
#    'ranking': 3,
#    'song': 'Jump',
#    'songurl': '/wiki/Kris_Kross',
#    'title': 'Jump',
#    'url': '/wiki/Jump_(Kris_Kross_song)'},
#   {'year': 1992,
#    'band_singer': 'Vanessa Williams',
#    'ranking': 4,
#    'song': 'Save the Best for Last',
#    'songurl': '/wiki/Vanessa_L._Williams',
#    'title': 'Save the Best for Last',
#    'url': '/wiki/Save_the_Best_for_Last'},
#   {'year': 1992,
#    'band_singer': 'TLC',
#    'ranking': 5,
#    'song': 'Baby-Baby-Baby',
#    'songurl': '/wiki/TLC_(band)',
#    'title': 'Baby-Baby-Baby',
#    'url': '/wiki/Baby-Baby-Baby'},
#   {'year': 1992,
#    'band_singer': 'Eric Clapton',
#    'ranking': 6,
#    'song': 'Tears in Heaven',
#    'songurl': '/wiki/Eric_Clapton',
#    'title': 'Tears in Heaven',
#    'url': '/wiki/Tears_in_Heaven'},
#   {'year': 1992,
#    'band_singer': 'En Vogue',
#    'ranking': 7,
#    'song': "My Lovin' (You're Never Gonna Get It)",
#    'songurl': '/wiki/En_Vogue',
#    'title': "My Lovin' (You're Never Gonna Get It)",
#    'url': '/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)'},
#   {'year': 1992,
#    'band_singer': 'Red Hot Chili Peppers',
#    'ranking': 8,
#    'song': 'Under the Bridge',
#    'songurl': '/wiki/Red_Hot_Chili_Peppers',
#    'title': 'Under the Bridge',
#    'url': '/wiki/Under_the_Bridge'},
#   {'year': 1992,
#    'band_singer': 'Color Me Badd',
#    'ranking': 9,
#    'song': 'All 4 Love',
#    'songurl': '/wiki/Color_Me_Badd',
#    'title': 'All 4 Love',
#    'url': '/wiki/All_4_Love'},
#   {'year': 1992,
#    'band_singer': 'Jon Secada',
#    'ranking': 10,
#    'song': 'Just Another Day',
#    'songurl': '/wiki/Jon_Secada',
#    'title': 'Just Another Day',
#    'url': '/wiki/Just_Another_Day_(Jon_Secada_song)'},
#   {'year': 1992,
#    'band_singer': 'Shanice',
#    'ranking': 11,
#    'song': 'I Love Your Smile',
#    'songurl': '/wiki/Shanice',
#    'title': 'I Love Your Smile',
#    'url': '/wiki/I_Love_Your_Smile'},
#   {'year': 1992,
#    'band_singer': 'Mr. Big',
#    'ranking': 12,
#    'song': 'To Be with You',
#    'songurl': '/wiki/Mr._Big_(band)',
#    'title': 'To Be with You',
#    'url': '/wiki/To_Be_with_You'},
#   {'year': 1992,
#    'band_singer': 'Right Said Fred',
#    'ranking': 13,
#    'song': "I'm Too Sexy",
#    'songurl': '/wiki/Right_Said_Fred',
#    'title': "I'm Too Sexy",
#    'url': '/wiki/I%27m_Too_Sexy'},
#   {'year': 1992,
#    'band_singer': 'Michael Jackson',
#    'ranking': 14,
#    'song': 'Black or White',
#    'songurl': '/wiki/Michael_Jackson',
#    'title': 'Black or White',
#    'url': '/wiki/Black_or_White'},
#   {'year': 1992,
#    'band_singer': 'Billy Ray Cyrus',
#    'ranking': 15,
#    'song': 'Achy Breaky Heart',
#    'songurl': '/wiki/Billy_Ray_Cyrus',
#    'title': 'Achy Breaky Heart',
#    'url': '/wiki/Achy_Breaky_Heart'},
#   {'year': 1992,
#    'band_singer': 'Mariah Carey',
#    'ranking': 16,
#    'song': "I'll Be There",
#    'songurl': '/wiki/Mariah_Carey',
#    'title': "I'll Be There",
#    'url': '/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mariah_Carey_version'},
#   {'year': 1992,
#    'band_singer': "Guns N' Roses",
#    'ranking': 17,
#    'song': 'November Rain',
#    'songurl': '/wiki/Guns_N%27_Roses',
#    'title': 'November Rain',
#    'url': '/wiki/November_Rain'},
#   {'year': 1992,
#    'band_singer': 'Tom Cochrane',
#    'ranking': 18,
#    'song': 'Life Is a Highway',
#    'songurl': '/wiki/Tom_Cochrane',
#    'title': 'Life Is a Highway',
#    'url': '/wiki/Life_Is_a_Highway'},
#   {'year': 1992,
#    'band_singer': 'Michael Jackson',
#    'ranking': 19,
#    'song': 'Remember the Time',
#    'songurl': '/wiki/Michael_Jackson',
#    'title': 'Remember the Time',
#    'url': '/wiki/Remember_the_Time'},
#   {'year': 1992,
#    'band_singer': 'CeCe Peniston',
#    'ranking': 20,
#    'song': 'Finally',
#    'songurl': '/wiki/CeCe_Peniston',
#    'title': 'Finally',
#    'url': '/wiki/Finally_(CeCe_Peniston_song)'},
#   {'year': 1992,
#    'band_singer': 'Madonna',
#    'ranking': 21,
#    'song': 'This Used to Be My Playground',
#    'songurl': '/wiki/Madonna_(entertainer)',
#    'title': 'This Used to Be My Playground',
#    'url': '/wiki/This_Used_to_Be_My_Playground'},
#   {'year': 1992,
#    'band_singer': 'Patty Smyth and Don Henley',
#    'ranking': 22,
#    'song': "Sometimes Love Just Ain't Enough",
#    'songurl': '/wiki/Patty_Smyth',
#    'title': "Sometimes Love Just Ain't Enough",
#    'url': '/wiki/Sometimes_Love_Just_Ain%27t_Enough'},
#   {'year': 1992,
#    'band_singer': 'Mariah Carey',
#    'ranking': 23,
#    'song': "Can't Let Go",
#    'songurl': '/wiki/Mariah_Carey',
#    'title': "Can't Let Go",
#    'url': '/wiki/Can%27t_Let_Go_(Mariah_Carey_song)'},
#   {'year': 1992,
#    'band_singer': 'House of Pain',
#    'ranking': 24,
#    'song': 'Jump Around',
#    'songurl': '/wiki/House_of_Pain',
#    'title': 'Jump Around',
#    'url': '/wiki/Jump_Around'},
#   {'year': 1992,
#    'band_singer': 'Prince and The New Power Generation',
#    'ranking': 25,
#    'song': 'Diamonds and Pearls',
#    'songurl': '/wiki/Prince_(entertainer)',
#    'title': 'Diamonds and Pearls',
#    'url': '/wiki/Diamonds_and_Pearls_(song)'},
#   {'year': 1992,
#    'band_singer': 'George Michael and Elton John',
#    'ranking': 26,
#    'song': "Don't Let the Sun Go Down on Me",
#    'songurl': '/wiki/George_Michael',
#    'title': "Don't Let the Sun Go Down on Me",
#    'url': '/wiki/Don%27t_Let_the_Sun_Go_Down_on_Me'},
#   {'year': 1992,
#    'band_singer': 'Atlantic Starr',
#    'ranking': 27,
#    'song': 'Masterpiece',
#    'songurl': '/wiki/Atlantic_Starr',
#    'title': 'Masterpiece',
#    'url': '/wiki/Masterpiece_(Atlantic_Starr_song)'},
#   {'year': 1992,
#    'band_singer': 'Celine Dion',
#    'ranking': 28,
#    'song': 'If You Asked Me To',
#    'songurl': '/wiki/Celine_Dion',
#    'title': 'If You Asked Me To',
#    'url': '/wiki/If_You_Asked_Me_To'},
#   {'year': 1992,
#    'band_singer': 'En Vogue',
#    'ranking': 29,
#    'song': 'Giving Him Something He Can Feel',
#    'songurl': '/wiki/En_Vogue',
#    'title': 'Giving Him Something He Can Feel',
#    'url': '/wiki/Something_He_Can_Feel'},
#   {'year': 1992,
#    'band_singer': 'Joe Public',
#    'ranking': 30,
#    'song': 'Live and Learn',
#    'songurl': '/wiki/Joe_Public_(band)',
#    'title': 'Live and Learn',
#    'url': '/wiki/Live_and_Learn_(Joe_Public_song)'},
#   {'year': 1992,
#    'band_singer': 'Jodeci',
#    'ranking': 31,
#    'song': 'Come and Talk to Me',
#    'songurl': '/wiki/Jodeci',
#    'title': 'Come and Talk to Me',
#    'url': '/wiki/Come_and_Talk_to_Me'},
#   {'year': 1992,
#    'band_singer': 'Nirvana',
#    'ranking': 32,
#    'song': 'Smells Like Teen Spirit',
#    'songurl': '/wiki/Nirvana_(band)',
#    'title': 'Smells Like Teen Spirit',
#    'url': '/wiki/Smells_Like_Teen_Spirit'},
#   {'year': 1992,
#    'band_singer': 'Bobby Brown',
#    'ranking': 33,
#    'song': "Humpin' Around",
#    'songurl': '/wiki/Bobby_Brown',
#    'title': "Humpin' Around",
#    'url': '/wiki/Humpin%27_Around'},
#   {'year': 1992,
#    'band_singer': 'Sophie B. Hawkins',
#    'ranking': 34,
#    'song': 'Damn I Wish I Was Your Lover',
#    'songurl': '/wiki/Sophie_B._Hawkins',
#    'title': 'Damn I Wish I Was Your Lover',
#    'url': '/wiki/Damn_I_Wish_I_Was_Your_Lover'},
#   {'year': 1992,
#    'band_singer': 'Tevin Campbell',
#    'ranking': 35,
#    'song': 'Tell Me What You Want Me to Do',
#    'songurl': '/wiki/Tevin_Campbell',
#    'title': 'Tell Me What You Want Me to Do',
#    'url': '/wiki/Tell_Me_What_You_Want_Me_to_Do'},
#   {'year': 1992,
#    'band_singer': 'TLC',
#    'ranking': 36,
#    'song': "Ain't 2 Proud 2 Beg",
#    'songurl': '/wiki/TLC_(band)',
#    'title': "Ain't 2 Proud 2 Beg",
#    'url': '/wiki/Ain%27t_2_Proud_2_Beg'},
#   {'year': 1992,
#    'band_singer': 'Boyz II Men',
#    'ranking': 37,
#    'song': "It's So Hard to Say Goodbye to Yesterday",
#    'songurl': '/wiki/Boyz_II_Men',
#    'title': "It's So Hard to Say Goodbye to Yesterday",
#    'url': '/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday'},
#   {'year': 1992,
#    'band_singer': 'Technotronic featuring Ya Kid K',
#    'ranking': 38,
#    'song': 'Move This',
#    'songurl': '/wiki/Technotronic',
#    'title': 'Move This',
#    'url': '/wiki/Move_This'},
#   {'year': 1992,
#    'band_singer': 'Queen',
#    'ranking': 39,
#    'song': 'Bohemian Rhapsody',
#    'songurl': '/wiki/Queen_(band)',
#    'title': 'Bohemian Rhapsody',
#    'url': '/wiki/Bohemian_Rhapsody'},
#   {'year': 1992,
#    'band_singer': 'Arrested Development',
#    'ranking': 40,
#    'song': 'Tennessee',
#    'songurl': '/wiki/Arrested_Development_(group)',
#    'title': 'Tennessee',
#    'url': '/wiki/Tennessee_(Arrested_Development_song)'},
#   {'year': 1992,
#    'band_singer': 'Luther Vandross and Janet Jackson',
#    'ranking': 41,
#    'song': 'The Best Things in Life Are Free',
#    'songurl': '/wiki/Luther_Vandross',
#    'title': 'The Best Things in Life Are Free',
#    'url': '/wiki/The_Best_Things_in_Life_Are_Free'},
#   {'year': 1992,
#    'band_singer': 'Mariah Carey',
#    'ranking': 42,
#    'song': 'Make It Happen',
#    'songurl': '/wiki/Mariah_Carey',
#    'title': 'Make It Happen',
#    'url': '/wiki/Make_It_Happen_(Mariah_Carey_song)'},
#   {'year': 1992,
#    'band_singer': 'Elton John',
#    'ranking': 43,
#    'song': 'The One',
#    'songurl': '/wiki/Elton_John',
#    'title': 'The One',
#    'url': '/wiki/The_One_(Elton_John_song)'},
#   {'year': 1992,
#    'band_singer': 'P.M. Dawn',
#    'ranking': 44,
#    'song': 'Set Adrift on Memory Bliss',
#    'songurl': '/wiki/P.M._Dawn',
#    'title': 'Set Adrift on Memory Bliss',
#    'url': '/wiki/Set_Adrift_on_Memory_Bliss'},
#   {'year': 1992,
#    'band_singer': 'Shakespears Sister',
#    'ranking': 45,
#    'song': 'Stay',
#    'songurl': '/wiki/Shakespears_Sister',
#    'title': 'Stay',
#    'url': '/wiki/Stay_(Shakespears_Sister_song)'},
#   {'year': 1992,
#    'band_singer': 'Hammer',
#    'ranking': 46,
#    'song': '2 Legit 2 Quit',
#    'songurl': '/wiki/MC_Hammer',
#    'title': '2 Legit 2 Quit',
#    'url': '/wiki/Too_Legit_to_Quit_(song)'},
#   {'year': 1992,
#    'band_singer': 'KWS',
#    'ranking': 47,
#    'song': "Please Don't Go",
#    'songurl': '/wiki/KWS_(band)',
#    'title': "Please Don't Go",
#    'url': '/wiki/Please_Don%27t_Go_(KC_and_the_Sunshine_Band_song)#KWS_version'},
#   {'year': 1992,
#    'band_singer': 'Mint Condition',
#    'ranking': 48,
#    'song': "Breakin' My Heart (Pretty Brown Eyes)",
#    'songurl': '/wiki/Mint_Condition',
#    'title': "Breakin' My Heart (Pretty Brown Eyes)",
#    'url': '/wiki/Breakin%27_My_Heart_(Pretty_Brown_Eyes)'},
#   {'year': 1992,
#    'band_singer': 'The Cover Girls',
#    'ranking': 49,
#    'song': 'Wishing on a Star',
#    'songurl': '/wiki/The_Cover_Girls',
#    'title': 'Wishing on a Star',
#    'url': '/wiki/Wishing_on_a_Star'},
#   {'year': 1992,
#    'band_singer': 'Hi-Five',
#    'ranking': 50,
#    'song': '"She\'s Playing Hard to Get"',
#    'songurl': '/wiki/Hi-Five',
#    'title': '"She\'s Playing Hard to Get"',
#    'url': None},
#   {'year': 1992,
#    'band_singer': 'P.M. Dawn',
#    'ranking': 51,
#    'song': "I'd Die Without You",
#    'songurl': '/wiki/P.M._Dawn',
#    'title': "I'd Die Without You",
#    'url': '/wiki/I%27d_Die_Without_You'},
#   {'year': 1992,
#    'band_singer': 'Amy Grant',
#    'ranking': 52,
#    'song': 'Good for Me',
#    'songurl': '/wiki/Amy_Grant',
#    'title': 'Good for Me',
#    'url': '/wiki/Good_for_Me_(song)'},
#   {'year': 1992,
#    'band_singer': 'Toad the Wet Sprocket',
#    'ranking': 53,
#    'song': 'All I Want',
#    'songurl': '/wiki/Toad_the_Wet_Sprocket',
#    'title': 'All I Want',
#    'url': '/wiki/All_I_Want_(Toad_the_Wet_Sprocket_song)'},
#   {'year': 1992,
#    'band_singer': 'Michael Bolton',
#    'ranking': 54,
#    'song': 'When a Man Loves a Woman',
#    'songurl': '/wiki/Michael_Bolton',
#    'title': 'When a Man Loves a Woman',
#    'url': '/wiki/When_a_Man_Loves_a_Woman_(song)'},
#   {'year': 1992,
#    'band_singer': 'Genesis',
#    'ranking': 55,
#    'song': "I Can't Dance",
#    'songurl': '/wiki/Genesis_(band)',
#    'title': "I Can't Dance",
#    'url': '/wiki/I_Can%27t_Dance'},
#   {'year': 1992,
#    'band_singer': 'Richard Marx',
#    'ranking': 56,
#    'song': 'Hazard',
#    'songurl': '/wiki/Richard_Marx',
#    'title': 'Hazard',
#    'url': '/wiki/Hazard_(song)'},
#   {'year': 1992,
#    'band_singer': 'U2',
#    'ranking': 57,
#    'song': 'Mysterious Ways',
#    'songurl': '/wiki/U2',
#    'title': 'Mysterious Ways',
#    'url': '/wiki/Mysterious_Ways_(song)'},
#   {'year': 1992,
#    'band_singer': 'George Michael',
#    'ranking': 58,
#    'song': 'Too Funky',
#    'songurl': '/wiki/George_Michael',
#    'title': 'Too Funky',
#    'url': '/wiki/Too_Funky'},
#   {'year': 1992,
#    'band_singer': 'The Heights',
#    'ranking': 59,
#    'song': 'How Do You Talk to an Angel',
#    'songurl': '/wiki/The_Heights_(American_TV_series)',
#    'title': 'How Do You Talk to an Angel',
#    'url': '/wiki/How_Do_You_Talk_to_an_Angel'},
#   {'year': 1992,
#    'band_singer': 'U2',
#    'ranking': 60,
#    'song': 'One',
#    'songurl': '/wiki/U2',
#    'title': 'One',
#    'url': '/wiki/One_(U2_song)'},
#   {'year': 1992,
#    'band_singer': 'CeCe Peniston',
#    'ranking': 61,
#    'song': "Keep on Walkin'",
#    'songurl': '/wiki/CeCe_Peniston',
#    'title': "Keep on Walkin'",
#    'url': '/wiki/Keep_on_Walkin%27_(song)'},
#   {'year': 1992,
#    'band_singer': 'Genesis',
#    'ranking': 62,
#    'song': 'Hold on My Heart',
#    'songurl': '/wiki/Genesis_(band)',
#    'title': 'Hold on My Heart',
#    'url': '/wiki/Hold_on_My_Heart'},
#   {'year': 1992,
#    'band_singer': 'Karyn White',
#    'ranking': 63,
#    'song': '"The Way I Feel About You"',
#    'songurl': '/wiki/Karyn_White',
#    'title': '"The Way I Feel About You"',
#    'url': None},
#   {'year': 1992,
#    'band_singer': 'Celine Dion and Peabo Bryson',
#    'ranking': 64,
#    'song': 'Beauty and the Beast',
#    'songurl': '/wiki/Celine_Dion',
#    'title': 'Beauty and the Beast',
#    'url': '/wiki/Beauty_and_the_Beast_(Disney_song)'},
#   {'year': 1992,
#    'band_singer': 'Kris Kross',
#    'ranking': 65,
#    'song': 'Warm It Up',
#    'songurl': '/wiki/Kris_Kross',
#    'title': 'Warm It Up',
#    'url': '/wiki/Warm_It_Up'},
#   {'year': 1992,
#    'band_singer': 'Michael Jackson',
#    'ranking': 66,
#    'song': 'In the Closet',
#    'songurl': '/wiki/Michael_Jackson',
#    'title': 'In the Closet',
#    'url': '/wiki/In_the_Closet'},
#   {'year': 1992,
#    'band_singer': 'Arrested Development',
#    'ranking': 67,
#    'song': 'People Everyday',
#    'songurl': '/wiki/Arrested_Development_(group)',
#    'title': 'People Everyday',
#    'url': '/wiki/People_Everyday'},
#   {'year': 1992,
#    'band_singer': 'Genesis',
#    'ranking': 68,
#    'song': 'No Son of Mine',
#    'songurl': '/wiki/Genesis_(band)',
#    'title': 'No Son of Mine',
#    'url': '/wiki/No_Son_of_Mine'},
#   {'year': 1992,
#    'band_singer': 'Marky Mark and the Funky Bunch',
#    'ranking': 69,
#    'song': 'Wildside',
#    'songurl': '/wiki/Marky_Mark_and_the_Funky_Bunch',
#    'title': 'Wildside',
#    'url': '/wiki/Wildside_(Marky_Mark_and_the_Funky_Bunch_song)'},
#   {'year': 1992,
#    'band_singer': 'Bryan Adams',
#    'ranking': 70,
#    'song': 'Do I Have to Say the Words?',
#    'songurl': '/wiki/Bryan_Adams',
#    'title': 'Do I Have to Say the Words?',
#    'url': '/wiki/Do_I_Have_to_Say_the_Words%3F'},
#   {'year': 1992,
#    'band_singer': 'The Cure',
#    'ranking': 71,
#    'song': "Friday I'm in Love",
#    'songurl': '/wiki/The_Cure',
#    'title': "Friday I'm in Love",
#    'url': '/wiki/Friday_I%27m_in_Love'},
#   {'year': 1992,
#    'band_singer': 'Ugly Kid Joe',
#    'ranking': 72,
#    'song': 'Everything About You',
#    'songurl': '/wiki/Ugly_Kid_Joe',
#    'title': 'Everything About You',
#    'url': '/wiki/Everything_About_You_(Ugly_Kid_Joe_song)'},
#   {'year': 1992,
#    'band_singer': 'Paula Abdul',
#    'ranking': 73,
#    'song': 'Blowing Kisses in the Wind',
#    'songurl': '/wiki/Paula_Abdul',
#    'title': 'Blowing Kisses in the Wind',
#    'url': '/wiki/Blowing_Kisses_in_the_Wind'},
#   {'year': 1992,
#    'band_singer': 'Bryan Adams',
#    'ranking': 74,
#    'song': "Thought I'd Died and Gone to Heaven",
#    'songurl': '/wiki/Bryan_Adams',
#    'title': "Thought I'd Died and Gone to Heaven",
#    'url': '/wiki/Thought_I%27d_Died_and_Gone_to_Heaven'},
#   {'year': 1992,
#    'band_singer': 'Snap!',
#    'ranking': 75,
#    'song': 'Rhythm Is a Dancer',
#    'songurl': '/wiki/Snap!',
#    'title': 'Rhythm Is a Dancer',
#    'url': '/wiki/Rhythm_Is_a_Dancer'},
#   {'year': 1992,
#    'band_singer': 'Hammer',
#    'ranking': 76,
#    'song': 'Addams Groove',
#    'songurl': '/wiki/MC_Hammer',
#    'title': 'Addams Groove',
#    'url': '/wiki/Addams_Groove'},
#   {'year': 1992,
#    'band_singer': 'Michael Bolton',
#    'ranking': 77,
#    'song': 'Missing You Now',
#    'songurl': '/wiki/Michael_Bolton',
#    'title': 'Missing You Now',
#    'url': '/wiki/Missing_You_Now'},
#   {'year': 1992,
#    'band_singer': 'N2Deep',
#    'ranking': 78,
#    'song': '"Back to the Hotel"',
#    'songurl': '/wiki/N2Deep',
#    'title': '"Back to the Hotel"',
#    'url': None},
#   {'year': 1992,
#    'band_singer': 'Kathy Troccoli',
#    'ranking': 79,
#    'song': '"Everything Changes"',
#    'songurl': '/wiki/Kathy_Troccoli',
#    'title': '"Everything Changes"',
#    'url': None},
#   {'year': 1992,
#    'band_singer': 'Def Leppard',
#    'ranking': 80,
#    'song': 'Have You Ever Needed Someone So Bad',
#    'songurl': '/wiki/Def_Leppard',
#    'title': 'Have You Ever Needed Someone So Bad',
#    'url': '/wiki/Have_You_Ever_Needed_Someone_So_Bad'},
#   {'year': 1992,
#    'band_singer': 'Richard Marx',
#    'ranking': 81,
#    'song': 'Take This Heart',
#    'songurl': '/wiki/Richard_Marx',
#    'title': 'Take This Heart',
#    'url': '/wiki/Take_This_Heart'},
#   {'year': 1992,
#    'band_singer': 'FireHouse',
#    'ranking': 82,
#    'song': 'When I Look Into Your Eyes',
#    'songurl': '/wiki/FireHouse_(band)',
#    'title': 'When I Look Into Your Eyes',
#    'url': '/wiki/When_I_Look_Into_Your_Eyes'},
#   {'year': 1992,
#    'band_singer': 'Jade',
#    'ranking': 83,
#    'song': 'I Wanna Love You',
#    'songurl': '/wiki/Jade_(American_band)',
#    'title': 'I Wanna Love You',
#    'url': '/wiki/I_Wanna_Love_You_(Jade_song)'},
#   {'year': 1992,
#    'band_singer': 'Boyz II Men',
#    'ranking': 84,
#    'song': 'Uhh Ahh',
#    'songurl': '/wiki/Boyz_II_Men',
#    'title': 'Uhh Ahh',
#    'url': '/wiki/Uhh_Ahh'},
#   {'year': 1992,
#    'band_singer': 'Mary J. Blige',
#    'ranking': 85,
#    'song': 'Real Love',
#    'songurl': '/wiki/Mary_J._Blige',
#    'title': 'Real Love',
#    'url': '/wiki/Real_Love_(Mary_J._Blige_song)'},
#   {'year': 1992,
#    'band_singer': 'The KLF',
#    'ranking': 86,
#    'song': 'Justified and Ancient',
#    'songurl': '/wiki/The_KLF',
#    'title': 'Justified and Ancient',
#    'url': '/wiki/Justified_and_Ancient'},
#   {'year': 1992,
#    'band_singer': 'Color Me Badd',
#    'ranking': 87,
#    'song': '"Slow Motion"',
#    'songurl': '/wiki/Color_Me_Badd',
#    'title': '"Slow Motion"',
#    'url': None},
#   {'year': 1992,
#    'band_singer': 'TLC',
#    'ranking': 88,
#    'song': 'What About Your Friends',
#    'songurl': '/wiki/TLC_(band)',
#    'title': 'What About Your Friends',
#    'url': '/wiki/What_About_Your_Friends'},
#   {'year': 1992,
#    'band_singer': 'Color Me Badd',
#    'ranking': 89,
#    'song': '"Thinkin\' Back"',
#    'songurl': '/wiki/Color_Me_Badd',
#    'title': '"Thinkin\' Back"',
#    'url': None},
#   {'year': 1992,
#    'band_singer': 'Charles & Eddie',
#    'ranking': 90,
#    'song': 'Would I Lie to You?',
#    'songurl': '/wiki/Charles_%26_Eddie',
#    'title': 'Would I Lie to You?',
#    'url': '/wiki/Would_I_Lie_to_You%3F_(Charles_%26_Eddie_song)'},
#   {'year': 1992,
#    'band_singer': 'Amy Grant',
#    'ranking': 91,
#    'song': "That's What Love Is For",
#    'songurl': '/wiki/Amy_Grant',
#    'title': "That's What Love Is For",
#    'url': '/wiki/That%27s_What_Love_Is_For'},
#   {'year': 1992,
#    'band_singer': 'Richard Marx',
#    'ranking': 92,
#    'song': 'Keep Coming Back',
#    'songurl': '/wiki/Richard_Marx',
#    'title': 'Keep Coming Back',
#    'url': '/wiki/Keep_Coming_Back_(song)'},
#   {'year': 1992,
#    'band_singer': 'En Vogue',
#    'ranking': 93,
#    'song': 'Free Your Mind',
#    'songurl': '/wiki/En_Vogue',
#    'title': 'Free Your Mind',
#    'url': '/wiki/Free_Your_Mind_(song)'},
#   {'year': 1992,
#    'band_singer': 'Keith Sweat',
#    'ranking': 94,
#    'song': "Keep It Comin'",
#    'songurl': '/wiki/Keith_Sweat',
#    'title': "Keep It Comin'",
#    'url': '/wiki/Keep_It_Comin%27_(song)'},
#   {'year': 1992,
#    'band_singer': 'Mr. Big',
#    'ranking': 95,
#    'song': 'Just Take My Heart',
#    'songurl': '/wiki/Mr._Big_(band)',
#    'title': 'Just Take My Heart',
#    'url': '/wiki/Just_Take_My_Heart_(song)'},
#   {'year': 1992,
#    'band_singer': 'Amy Grant',
#    'ranking': 96,
#    'song': 'I Will Remember You',
#    'songurl': '/wiki/Amy_Grant',
#    'title': 'I Will Remember You',
#    'url': '/wiki/I_Will_Remember_You_(Amy_Grant_song)'},
#   {'year': 1992,
#    'band_singer': 'CeCe Peniston',
#    'ranking': 97,
#    'song': 'We Got a Love Thang',
#    'songurl': '/wiki/CeCe_Peniston',
#    'title': 'We Got a Love Thang',
#    'url': '/wiki/We_Got_a_Love_Thang'},
#   {'year': 1992,
#    'band_singer': 'Def Leppard',
#    'ranking': 98,
#    'song': "Let's Get Rocked",
#    'songurl': '/wiki/Def_Leppard',
#    'title': "Let's Get Rocked",
#    'url': '/wiki/Let%27s_Get_Rocked'},
#   {'year': 1992,
#    'band_singer': 'Das EFX',
#    'ranking': 99,
#    'song': 'They Want EFX',
#    'songurl': '/wiki/Das_EFX',
#    'title': 'They Want EFX',
#    'url': '/wiki/They_Want_EFX'},
#   {'year': 1992,
#    'band_singer': 'Bonnie Raitt',
#    'ranking': 100,
#    'song': "I Can't Make You Love Me",
#    'songurl': '/wiki/Bonnie_Raitt',
#    'title': "I Can't Make You Love Me",
#    'url': '/wiki/I_Can%27t_Make_You_Love_Me'}],
#  1993: [{'year': 1993,
#    'band_singer': 'Whitney Houston',
#    'ranking': 1,
#    'song': 'I Will Always Love You',
#    'songurl': '/wiki/Whitney_Houston',
#    'title': 'I Will Always Love You',
#    'url': '/wiki/I_Will_Always_Love_You#Whitney_Houston_version'},
#   {'year': 1993,
#    'band_singer': 'Tag Team',
#    'ranking': 2,
#    'song': 'Whoomp! (There It Is)',
#    'songurl': '/wiki/Tag_Team_(group)',
#    'title': 'Whoomp! (There It Is)',
#    'url': '/wiki/Whoomp!_(There_It_Is)'},
#   {'year': 1993,
#    'band_singer': 'UB40',
#    'ranking': 3,
#    'song': "Can't Help Falling in Love",
#    'songurl': '/wiki/UB40',
#    'title': "Can't Help Falling in Love",
#    'url': '/wiki/Can%27t_Help_Falling_in_Love'},
#   {'year': 1993,
#    'band_singer': 'Janet Jackson',
#    'ranking': 4,
#    'song': "That's the Way Love Goes",
#    'songurl': '/wiki/Janet_Jackson',
#    'title': "That's the Way Love Goes",
#    'url': '/wiki/That%27s_the_Way_Love_Goes_(Janet_Jackson_song)'},
#   {'year': 1993,
#    'band_singer': 'Silk',
#    'ranking': 5,
#    'song': 'Freak Me',
#    'songurl': '/wiki/Silk_(group)',
#    'title': 'Freak Me',
#    'url': '/wiki/Freak_Me'},
#   {'year': 1993,
#    'band_singer': 'SWV',
#    'ranking': 6,
#    'song': 'Weak',
#    'songurl': '/wiki/SWV',
#    'title': 'Weak',
#    'url': '/wiki/Weak_(SWV_song)'},
#   {'year': 1993,
#    'band_singer': 'Shai',
#    'ranking': 7,
#    'song': 'If I Ever Fall in Love',
#    'songurl': '/wiki/Shai_(band)',
#    'title': 'If I Ever Fall in Love',
#    'url': '/wiki/If_I_Ever_Fall_in_Love'},
#   {'year': 1993,
#    'band_singer': 'Mariah Carey',
#    'ranking': 8,
#    'song': 'Dreamlover',
#    'songurl': '/wiki/Mariah_Carey',
#    'title': 'Dreamlover',
#    'url': '/wiki/Dreamlover_(song)'},
#   {'year': 1993,
#    'band_singer': 'Wreckx-n-Effect',
#    'ranking': 9,
#    'song': 'Rump Shaker',
#    'songurl': '/wiki/Wreckx-n-Effect',
#    'title': 'Rump Shaker',
#    'url': '/wiki/Rump_Shaker_(song)'},
#   {'year': 1993,
#    'band_singer': 'Snow',
#    'ranking': 10,
#    'song': 'Informer',
#    'songurl': '/wiki/Snow_(musician)',
#    'title': 'Informer',
#    'url': '/wiki/Informer_(song)'},
#   {'year': 1993,
#    'band_singer': 'Dr. Dre',
#    'ranking': 11,
#    'song': "Nuthin' but a 'G' Thang",
#    'songurl': '/wiki/Dr._Dre',
#    'title': "Nuthin' but a 'G' Thang",
#    'url': '/wiki/Nuthin%27_but_a_%27G%27_Thang'},
#   {'year': 1993,
#    'band_singer': 'Boyz II Men',
#    'ranking': 12,
#    'song': 'In the Still of the Nite',
#    'songurl': '/wiki/Boyz_II_Men',
#    'title': 'In the Still of the Nite',
#    'url': '/wiki/In_the_Still_of_the_Night_(1956_song)#Boyz_II_Men_version'},
#   {'year': 1993,
#    'band_singer': 'Jade',
#    'ranking': 13,
#    'song': "Don't Walk Away",
#    'songurl': '/wiki/Jade_(R%26B_group)',
#    'title': "Don't Walk Away",
#    'url': '/wiki/Don%27t_Walk_Away_(Jade_song)'},
#   {'year': 1993,
#    'band_singer': 'H-Town',
#    'ranking': 14,
#    'song': "Knockin' da Boots",
#    'songurl': '/wiki/H-Town_(band)',
#    'title': "Knockin' da Boots",
#    'url': '/wiki/Knockin%27_da_Boots'},
#   {'year': 1993,
#    'band_singer': 'Jodeci',
#    'ranking': 15,
#    'song': 'Lately',
#    'songurl': '/wiki/Jodeci',
#    'title': 'Lately',
#    'url': '/wiki/Lately_(Jodeci_song)'},
#   {'year': 1993,
#    'band_singer': 'Duice',
#    'ranking': 16,
#    'song': 'Dazzey Duks',
#    'songurl': '/wiki/Duice',
#    'title': 'Dazzey Duks',
#    'url': '/wiki/Dazzey_Duks'},
#   {'year': 1993,
#    'band_singer': 'Robin S.',
#    'ranking': 17,
#    'song': 'Show Me Love',
#    'songurl': '/wiki/Robin_S.',
#    'title': 'Show Me Love',
#    'url': '/wiki/Show_Me_Love_(Robin_S._song)'},
#   {'year': 1993,
#    'band_singer': 'Peabo Bryson and Regina Belle',
#    'ranking': 18,
#    'song': 'A Whole New World',
#    'songurl': '/wiki/Peabo_Bryson',
#    'title': 'A Whole New World',
#    'url': '/wiki/A_Whole_New_World'},
#   {'year': 1993,
#    'band_singer': 'Janet Jackson',
#    'ranking': 19,
#    'song': 'If',
#    'songurl': '/wiki/Janet_Jackson',
#    'title': 'If',
#    'url': '/wiki/If_(Janet_Jackson_song)'},
#   {'year': 1993,
#    'band_singer': 'SWV',
#    'ranking': 20,
#    'song': "I'm So Into You",
#    'songurl': '/wiki/SWV',
#    'title': "I'm So Into You",
#    'url': '/wiki/I%27m_So_Into_You'},
#   {'year': 1993,
#    'band_singer': 'Vanessa Williams and Brian McKnight',
#    'ranking': 21,
#    'song': 'Love Is',
#    'songurl': '/wiki/Vanessa_L._Williams',
#    'title': 'Love Is',
#    'url': '/wiki/Love_Is_(Vanessa_Williams_song)'},
#   {'year': 1993,
#    'band_singer': 'Soul Asylum',
#    'ranking': 22,
#    'song': 'Runaway Train',
#    'songurl': '/wiki/Soul_Asylum',
#    'title': 'Runaway Train',
#    'url': '/wiki/Runaway_Train_(Soul_Asylum_song)'},
#   {'year': 1993,
#    'band_singer': 'Exposé',
#    'ranking': 23,
#    'song': "I'll Never Get Over You (Getting Over Me)",
#    'songurl': '/wiki/Expos%C3%A9_(group)',
#    'title': "I'll Never Get Over You (Getting Over Me)",
#    'url': '/wiki/I%27ll_Never_Get_Over_You_(Getting_Over_Me)'},
#   {'year': 1993,
#    'band_singer': 'Paperboy',
#    'ranking': 24,
#    'song': 'Ditty',
#    'songurl': '/wiki/Paperboy_(rapper)',
#    'title': 'Ditty',
#    'url': '/wiki/Ditty_(Paperboy_song)'},
#   {'year': 1993,
#    'band_singer': 'Snap!',
#    'ranking': 25,
#    'song': 'Rhythm Is a Dancer',
#    'songurl': '/wiki/Snap!',
#    'title': 'Rhythm Is a Dancer',
#    'url': '/wiki/Rhythm_Is_a_Dancer'},
#   {'year': 1993,
#    'band_singer': 'Billy Joel',
#    'ranking': 26,
#    'song': 'The River of Dreams',
#    'songurl': '/wiki/Billy_Joel',
#    'title': 'The River of Dreams',
#    'url': '/wiki/The_River_of_Dreams'},
#   {'year': 1993,
#    'band_singer': 'The Proclaimers',
#    'ranking': 27,
#    'song': "I'm Gonna Be (500 Miles)",
#    'songurl': '/wiki/The_Proclaimers',
#    'title': "I'm Gonna Be (500 Miles)",
#    'url': '/wiki/I%27m_Gonna_Be_(500_Miles)'},
#   {'year': 1993,
#    'band_singer': 'Spin Doctors',
#    'ranking': 28,
#    'song': 'Two Princes',
#    'songurl': '/wiki/Spin_Doctors',
#    'title': 'Two Princes',
#    'url': '/wiki/Two_Princes'},
#   {'year': 1993,
#    'band_singer': 'SWV',
#    'ranking': 29,
#    'song': 'Right Here',
#    'songurl': '/wiki/SWV',
#    'title': 'Right Here',
#    'url': '/wiki/Right_Here_(SWV_song)'},
#   {'year': 1993,
#    'band_singer': 'Whitney Houston',
#    'ranking': 30,
#    'song': 'I Have Nothing',
#    'songurl': '/wiki/Whitney_Houston',
#    'title': 'I Have Nothing',
#    'url': '/wiki/I_Have_Nothing'},
#   {'year': 1993,
#    'band_singer': 'Arrested Development',
#    'ranking': 31,
#    'song': 'Mr. Wendal',
#    'songurl': '/wiki/Arrested_Development_(group)',
#    'title': 'Mr. Wendal',
#    'url': '/wiki/Mr._Wendal'},
#   {'year': 1993,
#    'band_singer': 'Rod Stewart',
#    'ranking': 32,
#    'song': 'Have I Told You Lately',
#    'songurl': '/wiki/Rod_Stewart',
#    'title': 'Have I Told You Lately',
#    'url': '/wiki/Have_I_Told_You_Lately'},
#   {'year': 1993,
#    'band_singer': 'Shanice',
#    'ranking': 33,
#    'song': 'Saving Forever for You',
#    'songurl': '/wiki/Shanice',
#    'title': 'Saving Forever for You',
#    'url': '/wiki/Saving_Forever_for_You'},
#   {'year': 1993,
#    'band_singer': 'Duran Duran',
#    'ranking': 34,
#    'song': 'Ordinary World',
#    'songurl': '/wiki/Duran_Duran',
#    'title': 'Ordinary World',
#    'url': '/wiki/Ordinary_World'},
#   {'year': 1993,
#    'band_singer': 'Tony! Toni! Toné!',
#    'ranking': 35,
#    'song': 'If I Had No Loot',
#    'songurl': '/wiki/Tony!_Toni!_Ton%C3%A9!',
#    'title': 'If I Had No Loot',
#    'url': '/wiki/If_I_Had_No_Loot'},
#   {'year': 1993,
#    'band_singer': 'Meat Loaf',
#    'ranking': 36,
#    'song': "I'd Do Anything for Love (But I Won't Do That)",
#    'songurl': '/wiki/Meat_Loaf',
#    'title': "I'd Do Anything for Love (But I Won't Do That)",
#    'url': '/wiki/I%27d_Do_Anything_for_Love_(But_I_Won%27t_Do_That)'},
#   {'year': 1993,
#    'band_singer': 'Onyx',
#    'ranking': 37,
#    'song': 'Slam',
#    'songurl': '/wiki/Onyx_(hip_hop_group)',
#    'title': 'Slam',
#    'url': '/wiki/Slam_(Onyx_song)'},
#   {'year': 1993,
#    'band_singer': 'P.M. Dawn',
#    'ranking': 38,
#    'song': 'Looking Through Patient Eyes',
#    'songurl': '/wiki/P.M._Dawn',
#    'title': 'Looking Through Patient Eyes',
#    'url': '/wiki/Looking_Through_Patient_Eyes'},
#   {'year': 1993,
#    'band_singer': 'Whitney Houston',
#    'ranking': 39,
#    'song': "I'm Every Woman",
#    'songurl': '/wiki/Whitney_Houston',
#    'title': "I'm Every Woman",
#    'url': '/wiki/I%27m_Every_Woman#Whitney_Houston_version'},
#   {'year': 1993,
#    'band_singer': 'Shai',
#    'ranking': 40,
#    'song': '"Baby I\'m Yours"',
#    'songurl': '/wiki/Shai_(band)',
#    'title': '"Baby I\'m Yours"',
#    'url': None},
#   {'year': 1993,
#    'band_singer': 'Duran Duran',
#    'ranking': 41,
#    'song': 'Come Undone',
#    'songurl': '/wiki/Duran_Duran',
#    'title': 'Come Undone',
#    'url': '/wiki/Come_Undone_(Duran_Duran_song)'},
#   {'year': 1993,
#    'band_singer': 'Tina Turner',
#    'ranking': 42,
#    'song': "I Don't Wanna Fight",
#    'songurl': '/wiki/Tina_Turner',
#    'title': "I Don't Wanna Fight",
#    'url': '/wiki/I_Don%27t_Wanna_Fight'},
#   {'year': 1993,
#    'band_singer': 'P.M. Dawn',
#    'ranking': 43,
#    'song': "I'd Die Without You",
#    'songurl': '/wiki/P.M._Dawn',
#    'title': "I'd Die Without You",
#    'url': '/wiki/I%27d_Die_Without_You'},
#   {'year': 1993,
#    'band_singer': '95 South',
#    'ranking': 44,
#    'song': 'Whoot, There It Is',
#    'songurl': '/wiki/95_South',
#    'title': 'Whoot, There It Is',
#    'url': '/wiki/Whoot,_There_It_Is'},
#   {'year': 1993,
#    'band_singer': 'Naughty by Nature',
#    'ranking': 45,
#    'song': 'Hip Hop Hooray',
#    'songurl': '/wiki/Naughty_by_Nature',
#    'title': 'Hip Hop Hooray',
#    'url': '/wiki/Hip_Hop_Hooray'},
#   {'year': 1993,
#    'band_singer': 'Toni Braxton',
#    'ranking': 46,
#    'song': 'Another Sad Love Song',
#    'songurl': '/wiki/Toni_Braxton',
#    'title': 'Another Sad Love Song',
#    'url': '/wiki/Another_Sad_Love_Song'},
#   {'year': 1993,
#    'band_singer': 'Michael Jackson',
#    'ranking': 47,
#    'song': 'Will You Be There',
#    'songurl': '/wiki/Michael_Jackson',
#    'title': 'Will You Be There',
#    'url': '/wiki/Will_You_Be_There'},
#   {'year': 1993,
#    'band_singer': 'Shai',
#    'ranking': 48,
#    'song': 'Comforter',
#    'songurl': '/wiki/Shai_(band)',
#    'title': 'Comforter',
#    'url': '/wiki/Comforter_(song)'},
#   {'year': 1993,
#    'band_singer': 'Bobby Brown',
#    'ranking': 49,
#    'song': '"Good Enough"',
#    'songurl': '/wiki/Bobby_Brown',
#    'title': '"Good Enough"',
#    'url': None},
#   {'year': 1993,
#    'band_singer': '4 Non Blondes',
#    'ranking': 50,
#    'song': "What's Up?",
#    'songurl': '/wiki/4_Non_Blondes',
#    'title': "What's Up?",
#    'url': '/wiki/What%27s_Up%3F_(4_Non_Blondes_song)'},
#   {'year': 1993,
#    'band_singer': 'Ace of Base',
#    'ranking': 51,
#    'song': 'All That She Wants',
#    'songurl': '/wiki/Ace_of_Base',
#    'title': 'All That She Wants',
#    'url': '/wiki/All_That_She_Wants'},
#   {'year': 1993,
#    'band_singer': 'Prince and The New Power Generation',
#    'ranking': 52,
#    'song': '7',
#    'songurl': '/wiki/Prince_(musician)',
#    'title': '7',
#    'url': '/wiki/7_(song)'},
#   {'year': 1993,
#    'band_singer': 'Dr. Dre featuring Snoop Doggy Dogg',
#    'ranking': 53,
#    'song': 'Dre Day',
#    'songurl': '/wiki/Dr._Dre',
#    'title': 'Dre Day',
#    'url': '/wiki/Fuck_wit_Dre_Day_(And_Everybody%27s_Celebratin%27)'},
#   {'year': 1993,
#    'band_singer': 'Brian McKnight',
#    'ranking': 54,
#    'song': 'One Last Cry',
#    'songurl': '/wiki/Brian_McKnight',
#    'title': 'One Last Cry',
#    'url': '/wiki/One_Last_Cry'},
#   {'year': 1993,
#    'band_singer': 'Xscape',
#    'ranking': 55,
#    'song': "Just Kickin' It",
#    'songurl': '/wiki/Xscape_(band)',
#    'title': "Just Kickin' It",
#    'url': '/wiki/Just_Kickin%27_It'},
#   {'year': 1993,
#    'band_singer': '2Pac',
#    'ranking': 56,
#    'song': 'I Get Around',
#    'songurl': '/wiki/Tupac_Shakur',
#    'title': 'I Get Around',
#    'url': '/wiki/I_Get_Around_(Tupac_Shakur_song)'},
#   {'year': 1993,
#    'band_singer': 'Bon Jovi',
#    'ranking': 57,
#    'song': 'Bed of Roses',
#    'songurl': '/wiki/Bon_Jovi',
#    'title': 'Bed of Roses',
#    'url': '/wiki/Bed_of_Roses_(Bon_Jovi_song)'},
#   {'year': 1993,
#    'band_singer': 'Mary J. Blige',
#    'ranking': 58,
#    'song': 'Real Love',
#    'songurl': '/wiki/Mary_J._Blige',
#    'title': 'Real Love',
#    'url': '/wiki/Real_Love_(Mary_J._Blige_song)'},
#   {'year': 1993,
#    'band_singer': 'Portrait',
#    'ranking': 59,
#    'song': '"Here We Go Again!"',
#    'songurl': '/wiki/Portrait_(band)',
#    'title': '"Here We Go Again!"',
#    'url': None},
#   {'year': 1993,
#    'band_singer': 'Aerosmith',
#    'ranking': 60,
#    'song': "Cryin'",
#    'songurl': '/wiki/Aerosmith',
#    'title': "Cryin'",
#    'url': '/wiki/Cryin%27'},
#   {'year': 1993,
#    'band_singer': 'Ugly Kid Joe',
#    'ranking': 61,
#    'song': "Cat's in the Cradle",
#    'songurl': '/wiki/Ugly_Kid_Joe',
#    'title': "Cat's in the Cradle",
#    'url': '/wiki/Cat%27s_in_the_Cradle'},
#   {'year': 1993,
#    'band_singer': 'TLC',
#    'ranking': 62,
#    'song': 'What About Your Friends',
#    'songurl': '/wiki/TLC_(group)',
#    'title': 'What About Your Friends',
#    'url': '/wiki/What_About_Your_Friends'},
#   {'year': 1993,
#    'band_singer': 'Positive K',
#    'ranking': 63,
#    'song': 'I Got a Man',
#    'songurl': '/wiki/Positive_K',
#    'title': 'I Got a Man',
#    'url': '/wiki/I_Got_a_Man'},
#   {'year': 1993,
#    'band_singer': 'Zhané',
#    'ranking': 64,
#    'song': 'Hey Mr. D.J.',
#    'songurl': '/wiki/Zhan%C3%A9',
#    'title': 'Hey Mr. D.J.',
#    'url': '/wiki/Hey_Mr._D.J.'},
#   {'year': 1993,
#    'band_singer': 'Cypress Hill',
#    'ranking': 65,
#    'song': 'Insane in the Brain',
#    'songurl': '/wiki/Cypress_Hill',
#    'title': 'Insane in the Brain',
#    'url': '/wiki/Insane_in_the_Brain'},
#   {'year': 1993,
#    'band_singer': 'Madonna',
#    'ranking': 66,
#    'song': 'Deeper and Deeper',
#    'songurl': '/wiki/Madonna_(entertainer)',
#    'title': 'Deeper and Deeper',
#    'url': '/wiki/Deeper_and_Deeper'},
#   {'year': 1993,
#    'band_singer': 'Madonna',
#    'ranking': 67,
#    'song': 'Rain',
#    'songurl': '/wiki/Madonna_(entertainer)',
#    'title': 'Rain',
#    'url': '/wiki/Rain_(Madonna_song)'},
#   {'year': 1993,
#    'band_singer': 'Jeremy Jordan',
#    'ranking': 68,
#    'song': 'The Right Kind of Love',
#    'songurl': '/wiki/Jeremy_Jordan_(singer,_born_1973)',
#    'title': 'The Right Kind of Love',
#    'url': '/wiki/The_Right_Kind_of_Love'},
#   {'year': 1993,
#    'band_singer': 'Inner Circle',
#    'ranking': 69,
#    'song': 'Bad Boys',
#    'songurl': '/wiki/Inner_Circle_(reggae_band)',
#    'title': 'Bad Boys',
#    'url': '/wiki/Bad_Boys_(Inner_Circle_song)'},
#   {'year': 1993,
#    'band_singer': 'Boy Krazy',
#    'ranking': 70,
#    'song': "That's What Love Can Do",
#    'songurl': '/wiki/Boy_Krazy',
#    'title': "That's What Love Can Do",
#    'url': '/wiki/That%27s_What_Love_Can_Do'},
#   {'year': 1993,
#    'band_singer': 'Jon Secada',
#    'ranking': 71,
#    'song': 'Do You Believe in Us',
#    'songurl': '/wiki/Jon_Secada',
#    'title': 'Do You Believe in Us',
#    'url': '/wiki/Do_You_Believe_in_Us'},
#   {'year': 1993,
#    'band_singer': 'Jon Secada',
#    'ranking': 72,
#    'song': 'Angel',
#    'songurl': '/wiki/Jon_Secada',
#    'title': 'Angel',
#    'url': '/wiki/Angel_(Jon_Secada_song)'},
#   {'year': 1993,
#    'band_singer': 'Kenny G',
#    'ranking': 73,
#    'song': 'Forever in Love',
#    'songurl': '/wiki/Kenny_G',
#    'title': 'Forever in Love',
#    'url': '/wiki/Forever_in_Love_(instrumental)'},
#   {'year': 1993,
#    'band_singer': 'Janet Jackson',
#    'ranking': 74,
#    'song': 'Again',
#    'songurl': '/wiki/Janet_Jackson',
#    'title': 'Again',
#    'url': '/wiki/Again_(Janet_Jackson_song)'},
#   {'year': 1993,
#    'band_singer': 'DJ Jazzy Jeff & The Fresh Prince',
#    'ranking': 75,
#    'song': 'Boom! Shake the Room',
#    'songurl': '/wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince',
#    'title': 'Boom! Shake the Room',
#    'url': '/wiki/Boom!_Shake_the_Room'},
#   {'year': 1993,
#    'band_singer': 'Restless Heart',
#    'ranking': 76,
#    'song': 'When She Cries',
#    'songurl': '/wiki/Restless_Heart',
#    'title': 'When She Cries',
#    'url': '/wiki/When_She_Cries'},
#   {'year': 1993,
#    'band_singer': 'Inner Circle',
#    'ranking': 77,
#    'song': 'Sweat (A La La La La Long)',
#    'songurl': '/wiki/Inner_Circle_(reggae_band)',
#    'title': 'Sweat (A La La La La Long)',
#    'url': '/wiki/Sweat_(A_La_La_La_La_Long)'},
#   {'year': 1993,
#    'band_singer': 'Ice Cube',
#    'ranking': 78,
#    'song': 'It Was a Good Day',
#    'songurl': '/wiki/Ice_Cube',
#    'title': 'It Was a Good Day',
#    'url': '/wiki/It_Was_a_Good_Day'},
#   {'year': 1993,
#    'band_singer': 'Captain Hollywood Project',
#    'ranking': 79,
#    'song': 'More and More',
#    'songurl': '/wiki/Captain_Hollywood_Project',
#    'title': 'More and More',
#    'url': '/wiki/More_and_More_(Captain_Hollywood_Project_song)'},
#   {'year': 1993,
#    'band_singer': 'The Heights',
#    'ranking': 80,
#    'song': 'How Do You Talk to an Angel',
#    'songurl': '/wiki/The_Heights_(American_TV_series)',
#    'title': 'How Do You Talk to an Angel',
#    'url': '/wiki/How_Do_You_Talk_to_an_Angel'},
#   {'year': 1993,
#    'band_singer': 'Digable Planets',
#    'ranking': 81,
#    'song': 'Rebirth of Slick (Cool Like Dat)',
#    'songurl': '/wiki/Digable_Planets',
#    'title': 'Rebirth of Slick (Cool Like Dat)',
#    'url': '/wiki/Rebirth_of_Slick_(Cool_Like_Dat)'},
#   {'year': 1993,
#    'band_singer': 'Haddaway',
#    'ranking': 82,
#    'song': 'What Is Love',
#    'songurl': '/wiki/Haddaway',
#    'title': 'What Is Love',
#    'url': '/wiki/What_Is_Love_(Haddaway_song)'},
#   {'year': 1993,
#    'band_singer': 'Michael Bolton',
#    'ranking': 83,
#    'song': 'To Love Somebody',
#    'songurl': '/wiki/Michael_Bolton',
#    'title': 'To Love Somebody',
#    'url': '/wiki/To_Love_Somebody_(song)'},
#   {'year': 1993,
#    'band_singer': 'En Vogue',
#    'ranking': 84,
#    'song': 'Give It Up, Turn It Loose',
#    'songurl': '/wiki/En_Vogue',
#    'title': 'Give It Up, Turn It Loose',
#    'url': '/wiki/Give_It_Up,_Turn_It_Loose'},
#   {'year': 1993,
#    'band_singer': 'Kris Kross',
#    'ranking': 85,
#    'song': 'Alright',
#    'songurl': '/wiki/Kris_Kross',
#    'title': 'Alright',
#    'url': '/wiki/Alright_(Kris_Kross_song)'},
#   {'year': 1993,
#    'band_singer': 'Ice Cube featuring Das EFX',
#    'ranking': 86,
#    'song': 'Check Yo Self',
#    'songurl': '/wiki/Ice_Cube',
#    'title': 'Check Yo Self',
#    'url': '/wiki/Check_Yo_Self'},
#   {'year': 1993,
#    'band_singer': 'Sting',
#    'ranking': 87,
#    'song': 'Fields of Gold',
#    'songurl': '/wiki/Sting_(musician)',
#    'title': 'Fields of Gold',
#    'url': '/wiki/Fields_of_Gold'},
#   {'year': 1993,
#    'band_singer': 'Dino',
#    'ranking': 88,
#    'song': 'Ooh Child',
#    'songurl': '/wiki/Dino_(singer)',
#    'title': 'Ooh Child',
#    'url': '/wiki/Ooh_Child'},
#   {'year': 1993,
#    'band_singer': 'Go West',
#    'ranking': 89,
#    'song': 'Faithful',
#    'songurl': '/wiki/Go_West_(band)',
#    'title': 'Faithful',
#    'url': '/wiki/Faithful_(Go_West_song)'},
#   {'year': 1993,
#    'band_singer': 'Rod Stewart',
#    'ranking': 90,
#    'song': 'Reason to Believe',
#    'songurl': '/wiki/Rod_Stewart',
#    'title': 'Reason to Believe',
#    'url': '/wiki/Reason_to_Believe'},
#   {'year': 1993,
#    'band_singer': 'Tears for Fears',
#    'ranking': 91,
#    'song': 'Break It Down Again',
#    'songurl': '/wiki/Tears_for_Fears',
#    'title': 'Break It Down Again',
#    'url': '/wiki/Break_It_Down_Again'},
#   {'year': 1993,
#    'band_singer': 'Joey Lawrence',
#    'ranking': 92,
#    'song': "Nothin' My Love Can't Fix",
#    'songurl': '/wiki/Joey_Lawrence',
#    'title': "Nothin' My Love Can't Fix",
#    'url': '/wiki/Nothin%27_My_Love_Can%27t_Fix'},
#   {'year': 1993,
#    'band_singer': 'Green Jellÿ',
#    'ranking': 93,
#    'song': 'Three Little Pigs',
#    'songurl': '/wiki/Green_Jell%C3%BF',
#    'title': 'Three Little Pigs',
#    'url': '/wiki/Three_Little_Pigs_(song)'},
#   {'year': 1993,
#    'band_singer': 'Aerosmith',
#    'ranking': 94,
#    'song': "Livin' on the Edge",
#    'songurl': '/wiki/Aerosmith',
#    'title': "Livin' on the Edge",
#    'url': '/wiki/Livin%27_on_the_Edge'},
#   {'year': 1993,
#    'band_singer': 'Gin Blossoms',
#    'ranking': 95,
#    'song': 'Hey Jealousy',
#    'songurl': '/wiki/Gin_Blossoms',
#    'title': 'Hey Jealousy',
#    'url': '/wiki/Hey_Jealousy'},
#   {'year': 1993,
#    'band_singer': 'Sting',
#    'ranking': 96,
#    'song': 'If I Ever Lose My Faith in You',
#    'songurl': '/wiki/Sting_(musician)',
#    'title': 'If I Ever Lose My Faith in You',
#    'url': '/wiki/If_I_Ever_Lose_My_Faith_in_You'},
#   {'year': 1993,
#    'band_singer': 'Tony! Toni! Toné!',
#    'ranking': 97,
#    'song': 'Anniversary',
#    'songurl': '/wiki/Tony!_Toni!_Ton%C3%A9!',
#    'title': 'Anniversary',
#    'url': '/wiki/Anniversary_(Tony!_Toni!_Ton%C3%A9!_song)'},
#   {'year': 1993,
#    'band_singer': 'Jade',
#    'ranking': 98,
#    'song': 'One Woman',
#    'songurl': '/wiki/Jade_(American_band)',
#    'title': 'One Woman',
#    'url': '/wiki/One_Woman'},
#   {'year': 1993,
#    'band_singer': 'Taylor Dayne',
#    'ranking': 99,
#    'song': "Can't Get Enough of Your Love",
#    'songurl': '/wiki/Taylor_Dayne',
#    'title': "Can't Get Enough of Your Love",
#    'url': '/wiki/Can%27t_Get_Enough_of_Your_Love#Taylor_Dayne_version'},
#   {'year': 1993,
#    'band_singer': 'Def Leppard',
#    'ranking': 100,
#    'song': 'Two Steps Behind',
#    'songurl': '/wiki/Def_Leppard',
#    'title': 'Two Steps Behind',
#    'url': '/wiki/Two_Steps_Behind'}],
#  1994: [{'year': 1994,
#    'band_singer': 'Ace of Base',
#    'ranking': 1,
#    'song': 'The Sign',
#    'songurl': '/wiki/Ace_of_Base',
#    'title': 'The Sign',
#    'url': '/wiki/The_Sign_(song)'},
#   {'year': 1994,
#    'band_singer': 'All-4-One',
#    'ranking': 2,
#    'song': 'I Swear',
#    'songurl': '/wiki/All-4-One',
#    'title': 'I Swear',
#    'url': '/wiki/I_Swear#All-4-One_version'},
#   {'year': 1994,
#    'band_singer': 'Boyz II Men',
#    'ranking': 3,
#    'song': "I'll Make Love to You",
#    'songurl': '/wiki/Boyz_II_Men',
#    'title': "I'll Make Love to You",
#    'url': '/wiki/I%27ll_Make_Love_to_You'},
#   {'year': 1994,
#    'band_singer': 'Céline Dion',
#    'ranking': 4,
#    'song': 'The Power of Love',
#    'songurl': '/wiki/C%C3%A9line_Dion',
#    'title': 'The Power of Love',
#    'url': '/wiki/The_Power_of_Love_(Jennifer_Rush_song)#Céline_Dion_version'},
#   {'year': 1994,
#    'band_singer': 'Mariah Carey',
#    'ranking': 5,
#    'song': 'Hero',
#    'songurl': '/wiki/Mariah_Carey',
#    'title': 'Hero',
#    'url': '/wiki/Hero_(Mariah_Carey_song)'},
#   {'year': 1994,
#    'band_singer': 'Lisa Loeb and Nine Stories',
#    'ranking': 6,
#    'song': 'Stay (I Missed You)',
#    'songurl': '/wiki/Lisa_Loeb',
#    'title': 'Stay (I Missed You)',
#    'url': '/wiki/Stay_(I_Missed_You)'},
#   {'year': 1994,
#    'band_singer': 'Toni Braxton',
#    'ranking': 7,
#    'song': 'Breathe Again',
#    'songurl': '/wiki/Toni_Braxton',
#    'title': 'Breathe Again',
#    'url': '/wiki/Breathe_Again'},
#   {'year': 1994,
#    'band_singer': 'Bryan Adams, Rod Stewart and Sting',
#    'ranking': 8,
#    'song': 'All for Love',
#    'songurl': '/wiki/Bryan_Adams',
#    'title': 'All for Love',
#    'url': '/wiki/All_for_Love_(song)'},
#   {'year': 1994,
#    'band_singer': 'Ace of Base',
#    'ranking': 9,
#    'song': 'All That She Wants',
#    'songurl': '/wiki/Ace_of_Base',
#    'title': 'All That She Wants',
#    'url': '/wiki/All_That_She_Wants'},
#   {'year': 1994,
#    'band_singer': 'Ace of Base',
#    'ranking': 10,
#    'song': "Don't Turn Around",
#    'songurl': '/wiki/Ace_of_Base',
#    'title': "Don't Turn Around",
#    'url': '/wiki/Don%27t_Turn_Around'},
#   {'year': 1994,
#    'band_singer': 'R. Kelly',
#    'ranking': 11,
#    'song': "Bump n' Grind",
#    'songurl': '/wiki/R._Kelly',
#    'title': "Bump n' Grind",
#    'url': '/wiki/Bump_n%27_Grind_(R._Kelly_song)'},
#   {'year': 1994,
#    'band_singer': 'Janet Jackson',
#    'ranking': 12,
#    'song': 'Again',
#    'songurl': '/wiki/Janet_Jackson',
#    'title': 'Again',
#    'url': '/wiki/Again_(Janet_Jackson_song)'},
#   {'year': 1994,
#    'band_singer': 'Madonna',
#    'ranking': 13,
#    'song': "I'll Remember",
#    'songurl': '/wiki/Madonna_(entertainer)',
#    'title': "I'll Remember",
#    'url': '/wiki/I%27ll_Remember'},
#   {'year': 1994,
#    'band_singer': 'Salt-n-Pepa and En Vogue',
#    'ranking': 14,
#    'song': 'Whatta Man',
#    'songurl': '/wiki/Salt-n-Pepa',
#    'title': 'Whatta Man',
#    'url': '/wiki/Whatta_Man'},
#   {'year': 1994,
#    'band_singer': 'John Mellencamp featuring Meshell Ndegeocello',
#    'ranking': 15,
#    'song': 'Wild Night',
#    'songurl': '/wiki/John_Mellencamp',
#    'title': 'Wild Night',
#    'url': '/wiki/Wild_Night'},
#   {'year': 1994,
#    'band_singer': 'Mariah Carey',
#    'ranking': 16,
#    'song': 'Without You',
#    'songurl': '/wiki/Mariah_Carey',
#    'title': 'Without You',
#    'url': '/wiki/Without_You_(Badfinger_song)#Mariah_Carey_version'},
#   {'year': 1994,
#    'band_singer': 'Toni Braxton',
#    'ranking': 17,
#    'song': 'You Mean the World to Me',
#    'songurl': '/wiki/Toni_Braxton',
#    'title': 'You Mean the World to Me',
#    'url': '/wiki/You_Mean_the_World_to_Me_(Toni_Braxton_song)'},
#   {'year': 1994,
#    'band_singer': 'Elton John',
#    'ranking': 18,
#    'song': 'Can You Feel the Love Tonight',
#    'songurl': '/wiki/Elton_John',
#    'title': 'Can You Feel the Love Tonight',
#    'url': '/wiki/Can_You_Feel_the_Love_Tonight'},
#   {'year': 1994,
#    'band_singer': 'Prince',
#    'ranking': 19,
#    'song': 'The Most Beautiful Girl in the World',
#    'songurl': '/wiki/Prince_(musician)',
#    'title': 'The Most Beautiful Girl in the World',
#    'url': '/wiki/The_Most_Beautiful_Girl_in_the_World_(Prince_song)'},
#   {'year': 1994,
#    'band_singer': 'Coolio',
#    'ranking': 20,
#    'song': 'Fantastic Voyage',
#    'songurl': '/wiki/Coolio',
#    'title': 'Fantastic Voyage',
#    'url': '/wiki/Fantastic_Voyage_(Coolio_song)'},
#   {'year': 1994,
#    'band_singer': 'Big Mountain',
#    'ranking': 21,
#    'song': 'Baby, I Love Your Way',
#    'songurl': '/wiki/Big_Mountain_(band)',
#    'title': 'Baby, I Love Your Way',
#    'url': '/wiki/Baby,_I_Love_Your_Way'},
#   {'year': 1994,
#    'band_singer': 'Warren G featuring Nate Dogg',
#    'ranking': 22,
#    'song': 'Regulate',
#    'songurl': '/wiki/Warren_G',
#    'title': 'Regulate',
#    'url': '/wiki/Regulate_(song)'},
#   {'year': 1994,
#    'band_singer': 'Jon Secada',
#    'ranking': 23,
#    'song': 'If You Go',
#    'songurl': '/wiki/Jon_Secada',
#    'title': 'If You Go',
#    'url': '/wiki/If_You_Go_(song)'},
#   {'year': 1994,
#    'band_singer': 'Aaliyah',
#    'ranking': 24,
#    'song': 'Back & Forth',
#    'songurl': '/wiki/Aaliyah',
#    'title': 'Back & Forth',
#    'url': '/wiki/Back_%26_Forth_(Aaliyah_song)'},
#   {'year': 1994,
#    'band_singer': 'Richard Marx',
#    'ranking': 25,
#    'song': 'Now and Forever',
#    'songurl': '/wiki/Richard_Marx',
#    'title': 'Now and Forever',
# ...
#    'song': 'Story of My Life',
#    'songurl': '/wiki/One_Direction',
#    'title': 'Story of My Life',
#    'url': '/wiki/Story_of_My_Life_(One_Direction_song)'},
#   {'year': 2014,
#    'band_singer': 'Sia',
#    'ranking': 25,
#    'song': 'Chandelier',
#    'songurl': '/wiki/Sia_Furler',
#    'title': 'Chandelier',
#    'url': '/wiki/Chandelier_(Sia_song)'},
#   {'year': 2014,
#    'band_singer': 'Iggy Azalea featuring Rita Ora',
#    'ranking': 26,
#    'song': 'Black Widow',
#    'songurl': '/wiki/Iggy_Azalea',
#    'title': 'Black Widow',
#    'url': '/wiki/Black_Widow_(Iggy_Azalea_song)'},
#   {'year': 2014,
#    'band_singer': 'Jessie J, Ariana Grande and Nicki Minaj',
#    'ranking': 27,
#    'song': 'Bang Bang',
#    'songurl': '/wiki/Jessie_J',
#    'title': 'Bang Bang',
#    'url': '/wiki/Bang_Bang_(Jessie_J,_Ariana_Grande_and_Nicki_Minaj_song)'},
#   {'year': 2014,
#    'band_singer': 'Disclosure featuring Sam Smith',
#    'ranking': 28,
#    'song': 'Latch',
#    'songurl': '/wiki/Disclosure_(band)',
#    'title': 'Latch',
#    'url': '/wiki/Latch_(song)'},
#   {'year': 2014,
#    'band_singer': 'Maroon 5',
#    'ranking': 29,
#    'song': 'Maps',
#    'songurl': '/wiki/Maroon_5',
#    'title': 'Maps',
#    'url': '/wiki/Maps_(Maroon_5_song)'},
#   {'year': 2014,
#    'band_singer': 'Chris Brown featuring Lil Wayne and French Montana or Too Short or Tyga',
#    'ranking': 30,
#    'song': 'Loyal',
#    'songurl': '/wiki/Chris_Brown',
#    'title': 'Loyal',
#    'url': '/wiki/Loyal_(Chris_Brown_song)'},
#   {'year': 2014,
#    'band_singer': 'American Authors',
#    'ranking': 31,
#    'song': 'Best Day of My Life',
#    'songurl': '/wiki/American_Authors',
#    'title': 'Best Day of My Life',
#    'url': '/wiki/Best_Day_of_My_Life'},
#   {'year': 2014,
#    'band_singer': 'Tove Lo',
#    'ranking': 32,
#    'song': 'Habits (Stay High)',
#    'songurl': '/wiki/Tove_Lo',
#    'title': 'Habits (Stay High)',
#    'url': '/wiki/Habits_(Stay_High)'},
#   {'year': 2014,
#    'band_singer': 'Calvin Harris',
#    'ranking': 33,
#    'song': 'Summer',
#    'songurl': '/wiki/Calvin_Harris',
#    'title': 'Summer',
#    'url': '/wiki/Summer_(Calvin_Harris_song)'},
#   {'year': 2014,
#    'band_singer': 'Charli XCX',
#    'ranking': 34,
#    'song': 'Boom Clap',
#    'songurl': '/wiki/Charli_XCX',
#    'title': 'Boom Clap',
#    'url': '/wiki/Boom_Clap'},
#   {'year': 2014,
#    'band_singer': 'Beyoncé featuring Jay-Z',
#    'ranking': 35,
#    'song': 'Drunk in Love',
#    'songurl': '/wiki/Beyonc%C3%A9',
#    'title': 'Drunk in Love',
#    'url': '/wiki/Drunk_in_Love'},
#   {'year': 2014,
#    'band_singer': 'Nicki Minaj',
#    'ranking': 36,
#    'song': 'Anaconda',
#    'songurl': '/wiki/Nicki_Minaj',
#    'title': 'Anaconda',
#    'url': '/wiki/Anaconda_(Nicki_Minaj_song)'},
#   {'year': 2014,
#    'band_singer': 'Ariana Grande featuring Zedd',
#    'ranking': 37,
#    'song': 'Break Free',
#    'songurl': '/wiki/Ariana_Grande',
#    'title': 'Break Free',
#    'url': '/wiki/Break_Free_(Ariana_Grande_song)'},
#   {'year': 2014,
#    'band_singer': 'Enrique Iglesias featuring Descemer Bueno and Gente de Zona',
#    'ranking': 38,
#    'song': 'Bailando',
#    'songurl': '/wiki/Enrique_Iglesias',
#    'title': 'Bailando',
#    'url': '/wiki/Bailando_(Enrique_Iglesias_song)'},
#   {'year': 2014,
#    'band_singer': 'Ellie Goulding',
#    'ranking': 39,
#    'song': 'Burn',
#    'songurl': '/wiki/Ellie_Goulding',
#    'title': 'Burn',
#    'url': '/wiki/Burn_(Ellie_Goulding_song)'},
#   {'year': 2014,
#    'band_singer': 'Jason Derulo featuring Snoop Dogg',
#    'ranking': 40,
#    'song': 'Wiggle',
#    'songurl': '/wiki/Jason_Derulo',
#    'title': 'Wiggle',
#    'url': '/wiki/Wiggle_(song)'},
#   {'year': 2014,
#    'band_singer': 'Clean Bandit featuring Jess Glynne',
#    'ranking': 41,
#    'song': 'Rather Be',
#    'songurl': '/wiki/Clean_Bandit',
#    'title': 'Rather Be',
#    'url': '/wiki/Rather_Be_(Clean_Bandit_song)'},
#   {'year': 2014,
#    'band_singer': 'Jeremih featuring YG',
#    'ranking': 42,
#    'song': "Don't Tell 'Em",
#    'songurl': '/wiki/Jeremih',
#    'title': "Don't Tell 'Em",
#    'url': '/wiki/Don%27t_Tell_%27Em'},
#   {'year': 2014,
#    'band_singer': 'Kid Ink featuring Chris Brown',
#    'ranking': 43,
#    'song': 'Show Me',
#    'songurl': '/wiki/Kid_Ink',
#    'title': 'Show Me',
#    'url': '/wiki/Show_Me_(Kid_Ink_song)'},
#   {'year': 2014,
#    'band_singer': 'Miley Cyrus',
#    'ranking': 44,
#    'song': 'Wrecking Ball',
#    'songurl': '/wiki/Miley_Cyrus',
#    'title': 'Wrecking Ball',
#    'url': '/wiki/Wrecking_Ball_(Miley_Cyrus_song)'},
#   {'year': 2014,
#    'band_singer': 'Justin Timberlake',
#    'ranking': 45,
#    'song': 'Not a Bad Thing',
#    'songurl': '/wiki/Justin_Timberlake',
#    'title': 'Not a Bad Thing',
#    'url': '/wiki/Not_a_Bad_Thing'},
#   {'year': 2014,
#    'band_singer': 'Katy Perry',
#    'ranking': 46,
#    'song': 'Roar',
#    'songurl': '/wiki/Katy_Perry',
#    'title': 'Roar',
#    'url': '/wiki/Roar_(song)'},
#   {'year': 2014,
#    'band_singer': 'Paramore',
#    'ranking': 47,
#    'song': "Ain't It Fun",
#    'songurl': '/wiki/Paramore',
#    'title': "Ain't It Fun",
#    'url': '/wiki/Ain%27t_It_Fun_(Paramore_song)'},
#   {'year': 2014,
#    'band_singer': 'Aloe Blacc',
#    'ranking': 48,
#    'song': 'The Man',
#    'songurl': '/wiki/Aloe_Blacc',
#    'title': 'The Man',
#    'url': '/wiki/The_Man_(Aloe_Blacc_song)'},
#   {'year': 2014,
#    'band_singer': 'Florida Georgia Line featuring Luke Bryan',
#    'ranking': 49,
#    'song': 'This Is How We Roll',
#    'songurl': '/wiki/Florida_Georgia_Line',
#    'title': 'This Is How We Roll',
#    'url': '/wiki/This_Is_How_We_Roll'},
#   {'year': 2014,
#    'band_singer': 'MKTO',
#    'ranking': 50,
#    'song': 'Classic',
#    'songurl': '/wiki/MKTO',
#    'title': 'Classic',
#    'url': '/wiki/Classic_(MKTO_song)'},
#   {'year': 2014,
#    'band_singer': 'Coldplay',
#    'ranking': 51,
#    'song': 'A Sky Full of Stars',
#    'songurl': '/wiki/Coldplay',
#    'title': 'A Sky Full of Stars',
#    'url': '/wiki/A_Sky_Full_of_Stars'},
#   {'year': 2014,
#    'band_singer': 'Ed Sheeran',
#    'ranking': 52,
#    'song': "Don't",
#    'songurl': '/wiki/Ed_Sheeran',
#    'title': "Don't",
#    'url': '/wiki/Don%27t_(Ed_Sheeran_song)'},
#   {'year': 2014,
#    'band_singer': 'Trey Songz',
#    'ranking': 53,
#    'song': 'Na Na',
#    'songurl': '/wiki/Trey_Songz',
#    'title': 'Na Na',
#    'url': '/wiki/Na_Na_(song)'},
#   {'year': 2014,
#    'band_singer': 'Bobby Shmurda',
#    'ranking': 54,
#    'song': 'Hot Boy',
#    'songurl': '/wiki/Bobby_Shmurda',
#    'title': 'Hot Boy',
#    'url': '/wiki/Hot_Nigga'},
#   {'year': 2014,
#    'band_singer': 'Drake featuring Majid Jordan',
#    'ranking': 55,
#    'song': "Hold On, We're Going Home",
#    'songurl': '/wiki/Drake_(rapper)',
#    'title': "Hold On, We're Going Home",
#    'url': '/wiki/Hold_On,_We%27re_Going_Home'},
#   {'year': 2014,
#    'band_singer': 'Ed Sheeran',
#    'ranking': 56,
#    'song': 'Sing',
#    'songurl': '/wiki/Ed_Sheeran',
#    'title': 'Sing',
#    'url': '/wiki/Sing_(Ed_Sheeran_song)'},
#   {'year': 2014,
#    'band_singer': 'Imagine Dragons',
#    'ranking': 57,
#    'song': 'Radioactive',
#    'songurl': '/wiki/Imagine_Dragons',
#    'title': 'Radioactive',
#    'url': '/wiki/Radioactive_(Imagine_Dragons_song)'},
#   {'year': 2014,
#    'band_singer': 'YG featuring Jeezy and Rich Homie Quan',
#    'ranking': 58,
#    'song': 'My Hitta',
#    'songurl': '/wiki/YG_(rapper)',
#    'title': 'My Hitta',
#    'url': '/wiki/My_Nigga'},
#   {'year': 2014,
#    'band_singer': 'Echosmith',
#    'ranking': 59,
#    'song': 'Cool Kids',
#    'songurl': '/wiki/Echosmith',
#    'title': 'Cool Kids',
#    'url': '/wiki/Cool_Kids_(Echosmith_song)'},
#   {'year': 2014,
#    'band_singer': 'Avicii',
#    'ranking': 60,
#    'song': 'Hey Brother',
#    'songurl': '/wiki/Avicii',
#    'title': 'Hey Brother',
#    'url': '/wiki/Hey_Brother'},
#   {'year': 2014,
#    'band_singer': 'Jason Derulo',
#    'ranking': 61,
#    'song': 'Trumpets',
#    'songurl': '/wiki/Jason_Derulo',
#    'title': 'Trumpets',
#    'url': '/wiki/Trumpets_(Jason_Derulo_song)'},
#   {'year': 2014,
#    'band_singer': 'Maroon 5',
#    'ranking': 62,
#    'song': 'Animals',
#    'songurl': '/wiki/Maroon_5',
#    'title': 'Animals',
#    'url': '/wiki/Animals_(Maroon_5_song)'},
#   {'year': 2014,
#    'band_singer': 'Jason Aldean',
#    'ranking': 63,
#    'song': "Burnin' It Down",
#    'songurl': '/wiki/Jason_Aldean',
#    'title': "Burnin' It Down",
#    'url': '/wiki/Burnin%27_It_Down'},
#   {'year': 2014,
#    'band_singer': 'Luke Bryan',
#    'ranking': 64,
#    'song': 'Play It Again',
#    'songurl': '/wiki/Luke_Bryan',
#    'title': 'Play It Again',
#    'url': '/wiki/Play_It_Again_(Luke_Bryan_song)'},
#   {'year': 2014,
#    'band_singer': 'Tinashe featuring ScHoolboy Q',
#    'ranking': 65,
#    'song': '2 On',
#    'songurl': '/wiki/Tinashe',
#    'title': '2 On',
#    'url': '/wiki/2_On'},
#   {'year': 2014,
#    'band_singer': 'Florida Georgia Line',
#    'ranking': 66,
#    'song': 'Dirt',
#    'songurl': '/wiki/Florida_Georgia_Line',
#    'title': 'Dirt',
#    'url': '/wiki/Dirt_(Florida_Georgia_Line_song)'},
#   {'year': 2014,
#    'band_singer': 'OneRepublic',
#    'ranking': 67,
#    'song': 'Love Runs Out',
#    'songurl': '/wiki/OneRepublic',
#    'title': 'Love Runs Out',
#    'url': '/wiki/Love_Runs_Out'},
#   {'year': 2014,
#    'band_singer': 'Brantley Gilbert',
#    'ranking': 68,
#    'song': 'Bottoms Up',
#    'songurl': '/wiki/Brantley_Gilbert',
#    'title': 'Bottoms Up',
#    'url': '/wiki/Bottoms_Up_(Brantley_Gilbert_song)'},
#   {'year': 2014,
#    'band_singer': 'Becky G',
#    'ranking': 69,
#    'song': 'Shower',
#    'songurl': '/wiki/Becky_G',
#    'title': 'Shower',
#    'url': '/wiki/Shower_(song)'},
#   {'year': 2014,
#    'band_singer': 'Rixton',
#    'ranking': 70,
#    'song': 'Me and My Broken Heart',
#    'songurl': '/wiki/Rixton_(band)',
#    'title': 'Me and My Broken Heart',
#    'url': '/wiki/Me_and_My_Broken_Heart'},
#   {'year': 2014,
#    'band_singer': 'Martin Garrix',
#    'ranking': 71,
#    'song': 'Animals',
#    'songurl': '/wiki/Martin_Garrix',
#    'title': 'Animals',
#    'url': '/wiki/Animals_(Martin_Garrix_composition)'},
#   {'year': 2014,
#    'band_singer': 'Rich Gang featuring Young Thug and Rich Homie Quan',
#    'ranking': 72,
#    'song': 'Lifestyle',
#    'songurl': '/wiki/Rich_Gang',
#    'title': 'Lifestyle',
#    'url': '/wiki/Lifestyle_(song)'},
#   {'year': 2014,
#    'band_singer': 'Kenny Chesney',
#    'ranking': 73,
#    'song': 'American Kids',
#    'songurl': '/wiki/Kenny_Chesney',
#    'title': 'American Kids',
#    'url': '/wiki/American_Kids'},
#   {'year': 2014,
#    'band_singer': 'Sara Bareilles',
#    'ranking': 74,
#    'song': 'Brave',
#    'songurl': '/wiki/Sara_Bareilles',
#    'title': 'Brave',
#    'url': '/wiki/Brave_(Sara_Bareilles_song)'},
#   {'year': 2014,
#    'band_singer': 'The Neighbourhood',
#    'ranking': 75,
#    'song': 'Sweater Weather',
#    'songurl': '/wiki/The_Neighbourhood',
#    'title': 'Sweater Weather',
#    'url': '/wiki/Sweater_Weather'},
#   {'year': 2014,
#    'band_singer': 'Sam Hunt',
#    'ranking': 76,
#    'song': 'Leave the Night On',
#    'songurl': '/wiki/Sam_Hunt',
#    'title': 'Leave the Night On',
#    'url': '/wiki/Leave_the_Night_On'},
#   {'year': 2014,
#    'band_singer': 'Chris Brown featuring Usher and Rick Ross',
#    'ranking': 77,
#    'song': 'New Flame',
#    'songurl': '/wiki/Chris_Brown',
#    'title': 'New Flame',
#    'url': '/wiki/New_Flame'},
#   {'year': 2014,
#    'band_singer': 'Michael Jackson and Justin Timberlake',
#    'ranking': 78,
#    'song': 'Love Never Felt So Good',
#    'songurl': '/wiki/Michael_Jackson',
#    'title': 'Love Never Felt So Good',
#    'url': '/wiki/Love_Never_Felt_So_Good'},
#   {'year': 2014,
#    'band_singer': 'Dierks Bentley',
#    'ranking': 79,
#    'song': 'Drunk on a Plane',
#    'songurl': '/wiki/Dierks_Bentley',
#    'title': 'Drunk on a Plane',
#    'url': '/wiki/Drunk_on_a_Plane'},
#   {'year': 2014,
#    'band_singer': 'Katy Perry',
#    'ranking': 80,
#    'song': 'Birthday',
#    'songurl': '/wiki/Katy_Perry',
#    'title': 'Birthday',
#    'url': '/wiki/Birthday_(Katy_Perry_song)'},
#   {'year': 2014,
#    'band_singer': 'Lady Antebellum',
#    'ranking': 81,
#    'song': 'Bartender',
#    'songurl': '/wiki/Lady_Antebellum',
#    'title': 'Bartender',
#    'url': '/wiki/Bartender_(Lady_Antebellum_song)'},
#   {'year': 2014,
#    'band_singer': 'Naughty Boy featuring Sam Smith',
#    'ranking': 82,
#    'song': 'La La La',
#    'songurl': '/wiki/Naughty_Boy',
#    'title': 'La La La',
#    'url': '/wiki/La_La_La_(Naughty_Boy_song)'},
#   {'year': 2014,
#    'band_singer': 'Robin Thicke featuring T.I. and Pharrell Williams',
#    'ranking': 83,
#    'song': 'Blurred Lines',
#    'songurl': '/wiki/Robin_Thicke',
#    'title': 'Blurred Lines',
#    'url': '/wiki/Blurred_Lines'},
#   {'year': 2014,
#    'band_singer': 'Lady Gaga featuring R. Kelly',
#    'ranking': 84,
#    'song': 'Do What U Want',
#    'songurl': '/wiki/Lady_Gaga',
#    'title': 'Do What U Want',
#    'url': '/wiki/Do_What_U_Want'},
#   {'year': 2014,
#    'band_singer': 'Shakira featuring Rihanna',
#    'ranking': 85,
#    'song': "Can't Remember to Forget You",
#    'songurl': '/wiki/Shakira',
#    'title': "Can't Remember to Forget You",
#    'url': '/wiki/Can%27t_Remember_to_Forget_You'},
#   {'year': 2014,
#    'band_singer': '5 Seconds of Summer',
#    'ranking': 86,
#    'song': 'Amnesia',
#    'songurl': '/wiki/5_Seconds_of_Summer',
#    'title': 'Amnesia',
#    'url': '/wiki/Amnesia_(5_Seconds_of_Summer_song)'},
#   {'year': 2014,
#    'band_singer': 'T.I. featuring Iggy Azalea',
#    'ranking': 87,
#    'song': 'No Mediocre',
#    'songurl': '/wiki/T.I.',
#    'title': 'No Mediocre',
#    'url': '/wiki/No_Mediocre'},
#   {'year': 2014,
#    'band_singer': 'KONGOS',
#    'ranking': 88,
#    'song': 'Come with Me Now',
#    'songurl': '/wiki/Kongos_(band)',
#    'title': 'Come with Me Now',
#    'url': '/wiki/Come_with_Me_Now'},
#   {'year': 2014,
#    'band_singer': 'Lil Wayne featuring Drake',
#    'ranking': 89,
#    'song': 'Believe Me',
#    'songurl': '/wiki/Lil_Wayne',
#    'title': 'Believe Me',
#    'url': '/wiki/Believe_Me_(Lil_Wayne_song)'},
#   {'year': 2014,
#    'band_singer': 'Mike WiLL Made-It featuring Miley Cyrus, Wiz Khalifa, and Juicy J',
#    'ranking': 90,
#    'song': '23',
#    'songurl': '/wiki/Mike_Will_Made_It',
#    'title': '23',
#    'url': '/wiki/23_(song)'},
#   {'year': 2014,
#    'band_singer': 'Jake Owen',
#    'ranking': 91,
#    'song': "Beachin'",
#    'songurl': '/wiki/Jake_Owen',
#    'title': "Beachin'",
#    'url': '/wiki/Beachin%27'},
#   {'year': 2014,
#    'band_singer': 'Macklemore & Ryan Lewis featuring ScHoolboy Q and Hollis',
#    'ranking': 92,
#    'song': 'White Walls',
#    'songurl': '/wiki/Macklemore_%26_Ryan_Lewis',
#    'title': 'White Walls',
#    'url': '/wiki/White_Walls'},
#   {'year': 2014,
#    'band_singer': '5 Seconds of Summer',
#    'ranking': 93,
#    'song': 'She Looks So Perfect',
#    'songurl': '/wiki/5_Seconds_of_Summer',
#    'title': 'She Looks So Perfect',
#    'url': '/wiki/She_Looks_So_Perfect'},
#   {'year': 2014,
#    'band_singer': 'Zedd featuring Hayley Williams',
#    'ranking': 94,
#    'song': 'Stay the Night',
#    'songurl': '/wiki/Zedd',
#    'title': 'Stay the Night',
#    'url': '/wiki/Stay_the_Night_(Zedd_song)'},
#   {'year': 2014,
#    'band_singer': 'Beyoncé',
#    'ranking': 95,
#    'song': 'Partition',
#    'songurl': '/wiki/Beyonc%C3%A9',
#    'title': 'Partition',
#    'url': '/wiki/Partition_(song)'},
#   {'year': 2014,
#    'band_singer': 'ScHoolboy Q featuring BJ the Chicago Kid',
#    'ranking': 96,
#    'song': 'Studio',
#    'songurl': '/wiki/ScHoolboy_Q',
#    'title': 'Studio',
#    'url': '/wiki/Studio_(song)'},
#   {'year': 2014,
#    'band_singer': 'Drake',
#    'ranking': 97,
#    'song': '0 to 100 / The Catch Up',
#    'songurl': '/wiki/Drake_(rapper)',
#    'title': '0 to 100 / The Catch Up',
#    'url': '/wiki/0_to_100_/_The_Catch_Up'},
#   {'year': 2014,
#    'band_singer': 'Lee Brice',
#    'ranking': 98,
#    'song': "I Don't Dance",
#    'songurl': '/wiki/Lee_Brice',
#    'title': "I Don't Dance",
#    'url': '/wiki/I_Don%27t_Dance_(Lee_Brice_song)'},
#   {'year': 2014,
#    'band_singer': 'Miranda Lambert and Carrie Underwood',
#    'ranking': 99,
#    'song': "Somethin' Bad",
#    'songurl': '/wiki/Miranda_Lambert',
#    'title': "Somethin' Bad",
#    'url': '/wiki/Somethin%27_Bad'},
#   {'year': 2014,
#    'band_singer': 'Miley Cyrus',
#    'ranking': 100,
#    'song': 'Adore You',
#    'songurl': '/wiki/Miley_Cyrus',
#    'title': 'Adore You',
#    'url': '/wiki/Adore_You'}]}

# %%
data = yearinfo

with open('yearinfo.json', 'w') as outfile:
    json.dump(data, outfile, indent=4)

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
fd = open("yearinfo.json","w")
json.dump(yearinfo, fd)
fd.close()
del yearinfo

# %% [markdown]
# Now let's reload our JSON file into the yearinfo variable, just to be sure everything is working.

# %%
# RERUN WHEN SUBMITTING
# Another way to deal with files. Has the advantage of closing the file for you.
with open("yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %% [markdown]
# #### 1.4 Construct a year-song-singer dataframe from the yearly information

# %% [markdown]
# Let's construct a dataframe `flatframe` from the `yearinfo`. The frame should be similar to the frame below.  Each row of the frame represents a song, and carries with it the chief properties of year, song, singer, and ranking.
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC1.png)

# %%
import pandas as pd

# %%
with open('yearinfo.json') as f:
    data = json.load(f)

# print(data)

# %%
from pandas.io.json import json_normalize
pdList = []
for i in range(1992,2016):
    df = pd.DataFrame.from_dict(json_normalize(top100songsyear[1992]), orient='columns')
    pdList.append(df)

# %%
top100 = pd.concat(pdList)

# %%
top100.shape
# Out:
# (2400, 7)

# %%
top100.head(4)
# Out:
#         band_singer  ranking                    song                    songurl                   title                           url  year
# 0       Boyz II Men        1         End of the Road          /wiki/Boyz_II_Men         End of the Road         /wiki/End_of_the_Road  1992
# 1     Sir Mix-a-Lot        2           Baby Got Back        /wiki/Sir_Mix-a-Lot           Baby Got Back           /wiki/Baby_Got_Back  1992
# 2        Kris Kross        3                    Jump           /wiki/Kris_Kross                    Jump  /wiki/Jump_(Kris_Kross_song)  1992
# 3  Vanessa Williams        4  Save the Best for Last  /wiki/Vanessa_L._Williams  Save the Best for Last  /wiki/Save_the_Best_for_Last  1992

# %% [markdown]
# To construct the dataframe, we'll need to iterate over the years and the singles per year. Notice how, above, the dataframe is ordered by ranking and then year. While the exact order is up to you, note that you will have to come up with a scheme to order the information.
#
# Check that the dataframe has sensible data types. You will also likely find that the year field has become an "object" (Pandas treats strings as generic objects): this is due to the conversion to and back from JSON. Such conversions need special care. Fix any data type issues with `flatframe`. (See Pandas [astype](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) function.)
# We will use this `flatframe` in the next question.
#
# (As an aside, we used the name `flatframe` to indicate that this dataframe is flattened from a hierarchical dictionary structure with the keys being the years.)

# %% [markdown]
# ### Who are the highest quality singers?

# %% [markdown]
# Here we show the highest quality singers and plot them on a bar chart.
#
# #### 1.5 Find highest quality singers according to how prolific they are
#
# What do we mean by highest quality? This is of course open to interpretation, but let's define "highest quality" here as the number of times a singer appears in the top 100 over this time period. If a singer appears twice in a year (for different songs), this is counted as two appearances, not one.
#
# Make a bar-plot of the most prolific singers. Singers on this chart should have appeared at-least more than 15 times. (HINT: look at the docs for the pandas method `value_counts`.)

# %%
artist_count = top100["band_singer"].value_counts()

artist_count
# Out:
# En Vogue                               72
# Mariah Carey                           72
# Boyz II Men                            72
# Color Me Badd                          72
# Amy Grant                              72
# CeCe Peniston                          72
# Michael Jackson                        72
# Richard Marx                           72
# TLC                                    72
# Genesis                                72
# Michael Bolton                         48
# Arrested Development                   48
# Kris Kross                             48
# U2                                     48
# Def Leppard                            48
# Hammer                                 48
# Bryan Adams                            48
# Mr. Big                                48
# P.M. Dawn                              48
# Atlantic Starr                         24
# George Michael and Elton John          24
# Paula Abdul                            24
# Luther Vandross and Janet Jackson      24
# Hi-Five                                24
# The Cure                               24
# Red Hot Chili Peppers                  24
# Mary J. Blige                          24
# House of Pain                          24
# Kathy Troccoli                         24
# Shanice                                24
#                                        ..
# Madonna                                24
# Karyn White                            24
# Queen                                  24
# Toad the Wet Sprocket                  24
# Jade                                   24
# The Heights                            24
# KWS                                    24
# Tom Cochrane                           24
# The KLF                                24
# Das EFX                                24
# Eric Clapton                           24
# Bobby Brown                            24
# Patty Smyth and Don Henley             24
# Technotronic featuring Ya Kid K        24
# Joe Public                             24
# Jodeci                                 24
# Celine Dion                            24
# Mint Condition                         24
# Marky Mark and the Funky Bunch         24
# Snap!                                  24
# Prince and The New Power Generation    24
# Sophie B. Hawkins                      24
# Bonnie Raitt                           24
# Celine Dion and Peabo Bryson           24
# George Michael                         24
# Guns N' Roses                          24
# The Cover Girls                        24
# Nirvana                                24
# FireHouse                              24
# Shakespears Sister                     24
# Name: band_singer, Length: 71, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(top100['band_singer'], bins=10, alpha=0.8)
plt.xlabel('band_singers')
plt.show()

# %% [markdown]
# #### 1.6 What if we used a different metric?

# %% [markdown]
# What we would like to capture is this: a singer should to be scored higher if the singer appears higher in the rankings. So we'd say that a singer who appeared once at a higher and once at a lower ranking is a "higher quality" singer than one who appeared twice at a lower ranking.
#
# To do this, group all of a singers songs together and assign each song a score `101 - ranking`. Order the singers by their total score and make a bar chart for the top 20.

# %% [markdown]
# #### 1.7 Do you notice any major differences when you change the metric?
#
# How have the singers at the top shifted places? Why do you think this happens?

# %% [markdown]
# ## Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia

# %% [markdown]
# Our next job is to use those band/singer urls we collected under `flatframe.url` and get information about singers and/or bands.

# %% [markdown]
# ### Scrape information about artists from wikipedia

# %% [markdown]
# We wish to fetch information about the singers or groups for all the winning songs in a list of years.
#
# Here we show a function that fetches information about a singer or group from their url on wikipedia. We create a cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Once we have fetched information about an artist, we don't need to do it again. The caching also helps if the network goes down, or the target website is having some problems. You simply need to run the `get_page` function below again, and the `urlcache` dictionary will continue to be filled.
#
# If the request gets an HTTP return code different from 200, (such as a 404 not found or 500 Internal Server Error) the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.
#
# Notice that we have wrapped the call in whats called _an exception block_. We try to make the request. If it fails entirely, or returns a HTTP code thats not 200, we set the status to 2 and 1 respectively.

# %%
urlcache={}

# %%
def get_page(url):
    # Check if URL has already been visited.
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        # try/except blocks are used whenever the code could generate an exception (e.g. division by zero).
        # In this case we don't know if the page really exists, or even if it does, if we'll be able to reach it.
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)

            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# We sort the `flatframe` by year, ascending, first. Think why.

# %%
flatframe= top100.sort_values('year')
print(flatframe.head())
urlcache
# Out:
#       band_singer  ranking                      song              songurl                     title                               url  year
# 0     Boyz II Men        1           End of the Road    /wiki/Boyz_II_Men           End of the Road             /wiki/End_of_the_Road  1992
# 96  CeCe Peniston       97       We Got a Love Thang  /wiki/CeCe_Peniston       We Got a Love Thang         /wiki/We_Got_a_Love_Thang  1992
# 97    Def Leppard       98          Let's Get Rocked    /wiki/Def_Leppard          Let's Get Rocked          /wiki/Let%27s_Get_Rocked  1992
# 98        Das EFX       99             They Want EFX        /wiki/Das_EFX             They Want EFX               /wiki/They_Want_EFX  1992
# 99   Bonnie Raitt      100  I Can't Make You Love Me   /wiki/Bonnie_Raitt  I Can't Make You Love Me  /wiki/I_Can%27t_Make_You_Love_Me  1992
# {}

# %% [markdown]
# #### Pulling and saving the data

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
# Here we are populating the url cache
# subsequent calls to this cell should be very fast, since Python won't
# need to fetch the page from the web server.
# NOTE this function will take quite some time to run (about 30 mins for me), since we sleep 1 second before
# making a request. If you run it again it will be almost instantaneous, save requests that might have failed
# (you will need to run it again if requests fail..see cell below for how to test this)
# flatframe["url"].apply(get_page)
print(flatframe['url'])
# Out:
# 0                                 /wiki/End_of_the_Road
# 96                            /wiki/We_Got_a_Love_Thang
# 97                             /wiki/Let%27s_Get_Rocked
# 98                                  /wiki/They_Want_EFX
# 99                     /wiki/I_Can%27t_Make_You_Love_Me
# 0                                 /wiki/End_of_the_Road
# 1                                   /wiki/Baby_Got_Back
# 95           /wiki/I_Will_Remember_You_(Amy_Grant_song)
# 2                          /wiki/Jump_(Kris_Kross_song)
# 4                                  /wiki/Baby-Baby-Baby
# 5                                 /wiki/Tears_in_Heaven
# 6       /wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)
# 7                                /wiki/Under_the_Bridge
# 8                                      /wiki/All_4_Love
# 9              /wiki/Just_Another_Day_(Jon_Secada_song)
# 3                          /wiki/Save_the_Best_for_Last
# 94                      /wiki/Just_Take_My_Heart_(song)
# 93                        /wiki/Keep_It_Comin%27_(song)
# 92                          /wiki/Free_Your_Mind_(song)
# 77                                                 None
# 78                                                 None
# 79            /wiki/Have_You_Ever_Needed_Someone_So_Bad
# 80                                /wiki/Take_This_Heart
# 81                     /wiki/When_I_Look_Into_Your_Eyes
# 82                   /wiki/I_Wanna_Love_You_(Jade_song)
# 83                                        /wiki/Uhh_Ahh
# 84                 /wiki/Real_Love_(Mary_J._Blige_song)
# 85                          /wiki/Justified_and_Ancient
# 86                                                 None
# 87                        /wiki/What_About_Your_Friends
#                             ...
# 14                              /wiki/Achy_Breaky_Heart
# 15    /wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mar...
# 16                                  /wiki/November_Rain
# 17                              /wiki/Life_Is_a_Highway
# 18                              /wiki/Remember_the_Time
# 19                   /wiki/Finally_(CeCe_Peniston_song)
# 20                  /wiki/This_Used_to_Be_My_Playground
# 21             /wiki/Sometimes_Love_Just_Ain%27t_Enough
# 22             /wiki/Can%27t_Let_Go_(Mariah_Carey_song)
# 7                                /wiki/Under_the_Bridge
# 87                        /wiki/What_About_Your_Friends
# 6       /wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)
# 4                                  /wiki/Baby-Baby-Baby
# 89    /wiki/Would_I_Lie_to_You%3F_(Charles_%26_Eddie...
# 90                      /wiki/That%27s_What_Love_Is_For
# 91                        /wiki/Keep_Coming_Back_(song)
# 92                          /wiki/Free_Your_Mind_(song)
# 93                        /wiki/Keep_It_Comin%27_(song)
# 94                      /wiki/Just_Take_My_Heart_(song)
# 95           /wiki/I_Will_Remember_You_(Amy_Grant_song)
# 96                            /wiki/We_Got_a_Love_Thang
# 97                             /wiki/Let%27s_Get_Rocked
# 98                                  /wiki/They_Want_EFX
# 99                     /wiki/I_Can%27t_Make_You_Love_Me
# 0                                 /wiki/End_of_the_Road
# 1                                   /wiki/Baby_Got_Back
# 2                          /wiki/Jump_(Kris_Kross_song)
# 3                          /wiki/Save_the_Best_for_Last
# 5                                 /wiki/Tears_in_Heaven
# 99                     /wiki/I_Can%27t_Make_You_Love_Me
# Name: url, Length: 2400, dtype: object

# %% [markdown]
# You may have to run this function again and again, in case there were network problems. Note that, because there is a "global" cache, it will take less time each time you run it. Also note that this function is designed to be run again and again: it attempts to make sure that there are no unresolved pages remaining. Let us make sure of this: *the sum below should be 0, and the boolean True.*

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
print("Number of bad requests:",np.sum([(urlcache[k]==1) or (urlcache[k]==2) for k in urlcache])) # no one or 0's)
print("Did we get all urls?", len(flatframe.url.unique())==len(urlcache)) # we got all of the urls
# Out:
# Number of bad requests: 95
# Did we get all urls? True

# %% [markdown]
# Let's save the `urlcache` to disk, just in case we need it again.

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
with open("yearinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %%
# RERUN WHEN SUBMITTING
with open("yearinfo.json") as json_file:
    urlcache = json.load(json_file)

# %% [markdown]
# #### 2.1 Extract information about singers and bands

# %% [markdown]
# From each page we collected about a singer or a band, extract the following information:
#
# 1. If the page has the text "Born" in the sidebar on the right, extract the element with the class `.bday`. If the page doesn't contain "Born", store `False`.  Store either of these into the variable `born`. We want to analyze the artist's age.
#
# 2. If the text "Years active" is found, but no "born", assume a band. Store into the variable `ya` the value of the next table cell corresponding to this, or `False` if the text is not found.
#
# Put this all into a function `singer_band_info` which takes the singer/band url as argument and returns a dictionary `dict(url=url, born=born, ya=ya)`.
#
# The information can be found on the sidebar on each such wikipedia page, as the example here shows:
#
# ![sandg](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/sandg.png).

# %% [markdown]
# Write the function `singer_band_info` according to the following specification:

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""


def singer_band_info(url, page_text):
    bday_dict = {}
    bday = ''
    ya = ''
    # soupify our webpage
    uClient = uReq(url)
    page_html = uClient.read()
    uClient.close()
    
    rsoup = soup(page_html)
    tables = rsoup.find('table', attrs={'class':'infobox vcard plainlist'})
    if (tables == None):
        tables = rsoup.find('table', attrs={'class':'infobox biography vcard'})
    bday = tables.find('span', {'class': 'bday'})
    if bday: 
        bday = bday.get_text()[:4]
        bday_dict = {'url' : url, 'born' : bday, 'ya' : ya}
    else:
        ya = False
        for tr in tables.find_all('tr'):
            if hasattr(tr.th, 'span'):
                if hasattr(tr.th.span, 'string'):
                    if tr.th.span.string == 'Years active':                
                        if hasattr(tr.th, 'span'):
                            #ya = tr.td.string
                            ya = tr.td.text   #DK add
                            bday = 'False'
                            bday_dict = {'url' : url, 'born' : 'False', 'ya' : ya}
    return(bday_dict)

# %% [markdown]
# #### 2.2  Merging this information in

# %%
url = 'https://en.wikipedia.org/wiki/Iggy_Azalea'
singer_band_info(url, urlcache)
# Out:
# {'url': 'https://en.wikipedia.org/wiki/Iggy_Azalea', 'born': '1990', 'ya': ''}

# %% [markdown]
# Iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a dataframe from there with columns `url`, `born`, and `ya`. Merge this dataframe on the `url` key with `flatframe`, creating a rather wide dataframe that we shall call `largedf`. It should look something like this:
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC3.png)
#
# Notice how the `born` and `ya` and `url` are repeated every time a different song from a given band is represented in a row.

# %% [markdown]
# #### 2.3 What is the age at which singers achieve their top ranking?

# %%
list_of_addit_dicts = []
bday_dict = {}
for url in urlcache.keys():   
    try:
        bday_dict = singer_band_info(url, urlcache)
        list_of_addit_dicts.append(bday_dict)
    except:
        break

# %% [markdown]
# Plot a histogram of the age at which singers achieve their top ranking. What conclusions can you draw from this distribution of ages?
#
# *HINT: You will need to do some manipulation of the `born` column, and find the song for which a band or an artist achieves their top ranking. You will then need to put these rows together into another dataframe or array to make the plot.*

# %% [markdown]
# #### 2.4 At what year since inception do bands reach their top rankings?

# %%
additional_df = pd.DataFrame(list_of_addit_dicts)
flatframe.head(100)
# Out:
#                             band_singer  ranking                                   song                      songurl                                  title                                              url  year
# 0                           Boyz II Men        1                        End of the Road            /wiki/Boyz_II_Men                        End of the Road                            /wiki/End_of_the_Road  1992
# 96                        CeCe Peniston       97                    We Got a Love Thang          /wiki/CeCe_Peniston                    We Got a Love Thang                        /wiki/We_Got_a_Love_Thang  1992
# 97                          Def Leppard       98                       Let's Get Rocked            /wiki/Def_Leppard                       Let's Get Rocked                         /wiki/Let%27s_Get_Rocked  1992
# 98                              Das EFX       99                          They Want EFX                /wiki/Das_EFX                          They Want EFX                              /wiki/They_Want_EFX  1992
# 99                         Bonnie Raitt      100               I Can't Make You Love Me           /wiki/Bonnie_Raitt               I Can't Make You Love Me                 /wiki/I_Can%27t_Make_You_Love_Me  1992
# 0                           Boyz II Men        1                        End of the Road            /wiki/Boyz_II_Men                        End of the Road                            /wiki/End_of_the_Road  1992
# 1                         Sir Mix-a-Lot        2                          Baby Got Back          /wiki/Sir_Mix-a-Lot                          Baby Got Back                              /wiki/Baby_Got_Back  1992
# 95                            Amy Grant       96                    I Will Remember You              /wiki/Amy_Grant                    I Will Remember You       /wiki/I_Will_Remember_You_(Amy_Grant_song)  1992
# 2                            Kris Kross        3                                   Jump             /wiki/Kris_Kross                                   Jump                     /wiki/Jump_(Kris_Kross_song)  1992
# 4                                   TLC        5                         Baby-Baby-Baby             /wiki/TLC_(band)                         Baby-Baby-Baby                             /wiki/Baby-Baby-Baby  1992
# 5                          Eric Clapton        6                        Tears in Heaven           /wiki/Eric_Clapton                        Tears in Heaven                            /wiki/Tears_in_Heaven  1992
# 6                              En Vogue        7  My Lovin' (You're Never Gonna Get It)               /wiki/En_Vogue  My Lovin' (You're Never Gonna Get It)  /wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)  1992
# 7                 Red Hot Chili Peppers        8                       Under the Bridge  /wiki/Red_Hot_Chili_Peppers                       Under the Bridge                           /wiki/Under_the_Bridge  1992
# 8                         Color Me Badd        9                             All 4 Love          /wiki/Color_Me_Badd                             All 4 Love                                 /wiki/All_4_Love  1992
# 9                            Jon Secada       10                       Just Another Day             /wiki/Jon_Secada                       Just Another Day         /wiki/Just_Another_Day_(Jon_Secada_song)  1992
# 3                      Vanessa Williams        4                 Save the Best for Last    /wiki/Vanessa_L._Williams                 Save the Best for Last                     /wiki/Save_the_Best_for_Last  1992
# 94                              Mr. Big       95                     Just Take My Heart         /wiki/Mr._Big_(band)                     Just Take My Heart                  /wiki/Just_Take_My_Heart_(song)  1992
# 93                          Keith Sweat       94                         Keep It Comin'            /wiki/Keith_Sweat                         Keep It Comin'                    /wiki/Keep_It_Comin%27_(song)  1992
# 92                             En Vogue       93                         Free Your Mind               /wiki/En_Vogue                         Free Your Mind                      /wiki/Free_Your_Mind_(song)  1992
# 77                               N2Deep       78                    "Back to the Hotel"                 /wiki/N2Deep                    "Back to the Hotel"                                             None  1992
# 78                       Kathy Troccoli       79                   "Everything Changes"         /wiki/Kathy_Troccoli                   "Everything Changes"                                             None  1992
# 79                          Def Leppard       80    Have You Ever Needed Someone So Bad            /wiki/Def_Leppard    Have You Ever Needed Someone So Bad        /wiki/Have_You_Ever_Needed_Someone_So_Bad  1992
# 80                         Richard Marx       81                        Take This Heart           /wiki/Richard_Marx                        Take This Heart                            /wiki/Take_This_Heart  1992
# 81                            FireHouse       82             When I Look Into Your Eyes       /wiki/FireHouse_(band)             When I Look Into Your Eyes                 /wiki/When_I_Look_Into_Your_Eyes  1992
# 82                                 Jade       83                       I Wanna Love You   /wiki/Jade_(American_band)                       I Wanna Love You               /wiki/I_Wanna_Love_You_(Jade_song)  1992
# 83                          Boyz II Men       84                                Uhh Ahh            /wiki/Boyz_II_Men                                Uhh Ahh                                    /wiki/Uhh_Ahh  1992
# 84                        Mary J. Blige       85                              Real Love          /wiki/Mary_J._Blige                              Real Love             /wiki/Real_Love_(Mary_J._Blige_song)  1992
# 85                              The KLF       86                  Justified and Ancient                /wiki/The_KLF                  Justified and Ancient                      /wiki/Justified_and_Ancient  1992
# 86                        Color Me Badd       87                          "Slow Motion"          /wiki/Color_Me_Badd                          "Slow Motion"                                             None  1992
# 87                                  TLC       88                What About Your Friends             /wiki/TLC_(band)                What About Your Friends                    /wiki/What_About_Your_Friends  1992
# ..                                  ...      ...                                    ...                          ...                                    ...                                              ...   ...
# 27                          Celine Dion       28                     If You Asked Me To            /wiki/Celine_Dion                     If You Asked Me To                         /wiki/If_You_Asked_Me_To  1992
# 28                             En Vogue       29       Giving Him Something He Can Feel               /wiki/En_Vogue       Giving Him Something He Can Feel                      /wiki/Something_He_Can_Feel  1992
# 30                               Jodeci       31                    Come and Talk to Me                 /wiki/Jodeci                    Come and Talk to Me                        /wiki/Come_and_Talk_to_Me  1992
# 48                      The Cover Girls       49                      Wishing on a Star        /wiki/The_Cover_Girls                      Wishing on a Star                          /wiki/Wishing_on_a_Star  1992
# 75                               Hammer       76                          Addams Groove              /wiki/MC_Hammer                          Addams Groove                              /wiki/Addams_Groove  1992
# 73                          Bryan Adams       74    Thought I'd Died and Gone to Heaven            /wiki/Bryan_Adams    Thought I'd Died and Gone to Heaven      /wiki/Thought_I%27d_Died_and_Gone_to_Heaven  1992
# 21           Patty Smyth and Don Henley       22       Sometimes Love Just Ain't Enough            /wiki/Patty_Smyth       Sometimes Love Just Ain't Enough         /wiki/Sometimes_Love_Just_Ain%27t_Enough  1992
# 22                         Mariah Carey       23                           Can't Let Go           /wiki/Mariah_Carey                           Can't Let Go         /wiki/Can%27t_Let_Go_(Mariah_Carey_song)  1992
# 23                        House of Pain       24                            Jump Around          /wiki/House_of_Pain                            Jump Around                                /wiki/Jump_Around  1992
# 24  Prince and The New Power Generation       25                    Diamonds and Pearls   /wiki/Prince_(entertainer)                    Diamonds and Pearls                 /wiki/Diamonds_and_Pearls_(song)  1992
# 25        George Michael and Elton John       26        Don't Let the Sun Go Down on Me         /wiki/George_Michael        Don't Let the Sun Go Down on Me          /wiki/Don%27t_Let_the_Sun_Go_Down_on_Me  1992
# 26                       Atlantic Starr       27                            Masterpiece         /wiki/Atlantic_Starr                            Masterpiece          /wiki/Masterpiece_(Atlantic_Starr_song)  1992
# 20                              Madonna       21          This Used to Be My Playground  /wiki/Madonna_(entertainer)          This Used to Be My Playground              /wiki/This_Used_to_Be_My_Playground  1992
# 27                          Celine Dion       28                     If You Asked Me To            /wiki/Celine_Dion                     If You Asked Me To                         /wiki/If_You_Asked_Me_To  1992
# 29                           Joe Public       30                         Live and Learn      /wiki/Joe_Public_(band)                         Live and Learn           /wiki/Live_and_Learn_(Joe_Public_song)  1992
# 30                               Jodeci       31                    Come and Talk to Me                 /wiki/Jodeci                    Come and Talk to Me                        /wiki/Come_and_Talk_to_Me  1992
# 31                              Nirvana       32                Smells Like Teen Spirit         /wiki/Nirvana_(band)                Smells Like Teen Spirit                    /wiki/Smells_Like_Teen_Spirit  1992
# 32                          Bobby Brown       33                         Humpin' Around            /wiki/Bobby_Brown                         Humpin' Around                           /wiki/Humpin%27_Around  1992
# 33                    Sophie B. Hawkins       34           Damn I Wish I Was Your Lover      /wiki/Sophie_B._Hawkins           Damn I Wish I Was Your Lover               /wiki/Damn_I_Wish_I_Was_Your_Lover  1992
# 34                       Tevin Campbell       35         Tell Me What You Want Me to Do         /wiki/Tevin_Campbell         Tell Me What You Want Me to Do             /wiki/Tell_Me_What_You_Want_Me_to_Do  1992
# 28                             En Vogue       29       Giving Him Something He Can Feel               /wiki/En_Vogue       Giving Him Something He Can Feel                      /wiki/Something_He_Can_Feel  1992
# 19                        CeCe Peniston       20                                Finally          /wiki/CeCe_Peniston                                Finally               /wiki/Finally_(CeCe_Peniston_song)  1992
# 18                      Michael Jackson       19                      Remember the Time        /wiki/Michael_Jackson                      Remember the Time                          /wiki/Remember_the_Time  1992
# 17                         Tom Cochrane       18                      Life Is a Highway           /wiki/Tom_Cochrane                      Life Is a Highway                          /wiki/Life_Is_a_Highway  1992
# 2                            Kris Kross        3                                   Jump             /wiki/Kris_Kross                                   Jump                     /wiki/Jump_(Kris_Kross_song)  1992
# 3                      Vanessa Williams        4                 Save the Best for Last    /wiki/Vanessa_L._Williams                 Save the Best for Last                     /wiki/Save_the_Best_for_Last  1992
# 4                                   TLC        5                         Baby-Baby-Baby             /wiki/TLC_(band)                         Baby-Baby-Baby                             /wiki/Baby-Baby-Baby  1992
# 5                          Eric Clapton        6                        Tears in Heaven           /wiki/Eric_Clapton                        Tears in Heaven                            /wiki/Tears_in_Heaven  1992
# 6                              En Vogue        7  My Lovin' (You're Never Gonna Get It)               /wiki/En_Vogue  My Lovin' (You're Never Gonna Get It)  /wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)  1992
# 7                 Red Hot Chili Peppers        8                       Under the Bridge  /wiki/Red_Hot_Chili_Peppers                       Under the Bridge                           /wiki/Under_the_Bridge  1992
#
# [100 rows x 7 columns]

# %% [markdown]
# Make a similar calculation to plot a histogram of the years since inception at which bands reach their top ranking. What conclusions can you draw?
